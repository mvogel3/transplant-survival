# %%
import pandas as pd

# %%
#In order to prevent having the first two rows of our raw excel data be the column names we are dropping
#the second row, although more readable, it sometimes vary slightly across Excel workbooks.
#To map the more descriptive "column name" to the acronym but better for data storing names, we are creating this
#legend.

#import an excel file from the 2012 to 2014 excel data to get the two column names
filepath = 'kidney/1207_KI.XLS'
sheet_name = 'Table 7 - Deceased'
df = pd.read_excel(filepath, sheet_name)

# %%
df.head()
# Out:
#                                Unnamed: 0  CTR_CD  CTR_TY  RELEASE_DATE  \
# 0  University of Alabama Hospital (ALUA)    ALUA     TX1    2012/07/13
# 1          Baptist Medical Center (ARBH)    ARBH     TX1    2012/07/13
# 2    Arkansas Children's Hospital (ARCH)    ARCH     TX1    2012/07/13
# 3             UAMS Medical Center (ARUA)    ARUA     TX1    2012/07/13
# 4     Phoenix Children's Hospital (AZCH)    AZCH     TX1    2012/07/13
#
#         ORG    D_OR_L  YEAR  MONTH   RCC_A10_C   RCC_A10_R  ...   RCC_TST2_C  \
# 0   Kidney   DECEASED  2012      7         2.8         1.3  ...
# 1   Kidney   DECEASED  2012      7         0.0         1.3  ...
# 2   Kidney   DECEASED  2012      7         0.0         1.3  ...
# 3   Kidney   DECEASED  2012      7         0.0         1.3  ...
# 4   Kidney   DECEASED  2012      7        80.0         1.7  ...
#
#     RCC_TST2_R   RCC_TST3_C   RCC_TST3_R   RCC_TUB_C   RCC_TUB_R   RCC_VAS_C  \
# ...

# %%
#drop everything except the column names and first row
df_col = df.iloc[[0]]
df_col.head()
# Out:
#                                Unnamed: 0  CTR_CD  CTR_TY  RELEASE_DATE  \
# 0  University of Alabama Hospital (ALUA)    ALUA     TX1    2012/07/13
#
#         ORG    D_OR_L  YEAR  MONTH   RCC_A10_C   RCC_A10_R  ...   RCC_TST2_C  \
# 0   Kidney   DECEASED  2012      7         2.8         1.3  ...
#
#     RCC_TST2_R   RCC_TST3_C   RCC_TST3_R   RCC_TUB_C   RCC_TUB_R   RCC_VAS_C  \
# 0                                                8.4         4.8         0.7
#
#     RCC_VAS_R   RCC_VHD_C   RCC_VHD_R
# 0         0.1
#
# [1 rows x 194 columns]

# %%
df_col.columns
# Out:
# Index(['Unnamed: 0', ' CTR_CD', ' CTR_TY', ' RELEASE_DATE', ' ORG', 'D_OR_L',
#        'YEAR', 'MONTH', ' RCC_A10_C', ' RCC_A10_R',
#        ...
#        ' RCC_TST2_C', ' RCC_TST2_R', ' RCC_TST3_C', ' RCC_TST3_R',
#        ' RCC_TUB_C', ' RCC_TUB_R', ' RCC_VAS_C', ' RCC_VAS_R', ' RCC_VHD_C',
#        ' RCC_VHD_R'],
#       dtype='object', length=194)

# %%
#transpose the columns into rows
df_col_transp = df_col.T
df_col_transp.head(30)
# Out:
#                                                     0
# Unnamed: 0     University of Alabama Hospital (ALUA)
#  CTR_CD                                         ALUA
#  CTR_TY                                          TX1
#  RELEASE_DATE                             2012/07/13
#  ORG                                          Kidney
# D_OR_L                                       DECEASED
# YEAR                                             2012
# MONTH                                               7
#  RCC_A10_C                                        2.8
#  RCC_A10_R                                        1.3
#  RCC_A17_C                                        6.3
#  RCC_A17_R                                        2.7
#  RCC_A2_C                                         0.7
#  RCC_A2_R                                         0.1
#  RCC_A34_C                                        9.8
#  RCC_A34_R                                        9.3
# ...

# %%
#send legend to EXCEL
#df_col_transp.to_excel('output/LEGEND_Table_7_Deceased.xlsx')
df_col.to_excel('output/COLUMNS_Table_7_Deceased.xlsx')

# %%
#import a post 2015 or later excel file
filepath = 'kidney/csrs_final_tables1506KI.XLS'
sheet_name = 'Figures C1-C2 - Deceased'
df_post = pd.read_excel(filepath, sheet_name)

# %%
df_post.head()
# Out:
#                                Unnamed: 0  CTR_CD  CTR_TY  RELEASE_DATE  \
# 0           Children's of Alabama (ALCH)    ALCH     TX1    2015/06/16
# 1  University of Alabama Hospital (ALUA)    ALUA     TX1    2015/06/16
# 2          Baptist Medical Center (ARBH)    ARBH     TX1    2015/06/16
# 3    Arkansas Children's Hospital (ARCH)    ARCH     TX1    2015/06/16
# 4             UAMS Medical Center (ARUA)    ARUA     TX1    2015/06/16
#
#         ORG    D_OR_L  YEAR  MONTH   RCC_A10_C   RCC_A10_R  ...   RCC_TST2_C  \
# 0   Kidney   DECEASED  2015      6        20.0         2.0  ...
# 1   Kidney   DECEASED  2015      6         0.0         2.0  ...
# 2   Kidney   DECEASED  2015      6         0.0         2.0  ...
# 3   Kidney   DECEASED  2015      6        66.7         2.0  ...
# 4   Kidney   DECEASED  2015      6         0.0         2.0  ...
#
#     RCC_TST2_R   RCC_TST3_C   RCC_TST3_R   RCC_TUB_C   RCC_TUB_R   RCC_VAS_C  \
# ...

# %%
#drop everything except the column names and first row
df_col_post = df_post.iloc[[0]]
df_col_post.head()
# Out:
#                       Unnamed: 0  CTR_CD  CTR_TY  RELEASE_DATE       ORG  \
# 0  Children's of Alabama (ALCH)    ALCH     TX1    2015/06/16    Kidney
#
#      D_OR_L  YEAR  MONTH   RCC_A10_C   RCC_A10_R  ...   RCC_TST2_C  \
# 0  DECEASED  2015      6        20.0         2.0  ...
#
#     RCC_TST2_R   RCC_TST3_C   RCC_TST3_R   RCC_TUB_C   RCC_TUB_R   RCC_VAS_C  \
# 0                                               13.3         4.0         0.0
#
#     RCC_VAS_R   RCC_VHD_C   RCC_VHD_R
# 0         0.1
#
# [1 rows x 194 columns]

# %%
#transpose the columns into rows
df_col_transp = df_col.T
df_col_transp.head(30)
# Out:
#                                                     0
# Unnamed: 0     University of Alabama Hospital (ALUA)
#  CTR_CD                                         ALUA
#  CTR_TY                                          TX1
#  RELEASE_DATE                             2012/07/13
#  ORG                                          Kidney
# D_OR_L                                       DECEASED
# YEAR                                             2012
# MONTH                                               7
#  RCC_A10_C                                        2.8
#  RCC_A10_R                                        1.3
#  RCC_A17_C                                        6.3
#  RCC_A17_R                                        2.7
#  RCC_A2_C                                         0.7
#  RCC_A2_R                                         0.1
#  RCC_A34_C                                        9.8
#  RCC_A34_R                                        9.3
# ...

# %%
#send legend to EXCEL
df_col_transp.to_excel('output/LEGEND_Figures_C1_C2_Deceased.xlsx')

# %%
filepath = 'kidney/csrs_final_tables_1905_KI.xls'
sheet_name = 'Figures C1-C2 - Deceased'
df_19 = pd.read_excel(filepath, sheet_name)

# %%
df_19.head()
# Out:
#                                    ENTIRE_NAME CTR_CD CTR_TY  \
# 0                     Hartford Hospital (CTHH)   CTHH    TX1
# 1               Yale New Haven Hospital (CTYN)   CTYN    TX1
# 2  Beth Israel Deaconess Medical Center (MABI)   MABI    TX1
# 3               Baystate Medical Center (MABS)   MABS    TX1
# 4                 Boston Medical Center (MABU)   MABU    TX1
#
#          RELEASE_DATE ORG    D_OR_L  YEAR  MONTH  RCC_A10_C  RCC_A10_R  ...  \
# 0 2019-07-07 19:00:00  KI  DECEASED  2019      5        0.0   1.303538  ...
# 1 2019-07-07 19:00:00  KI  DECEASED  2019      5        0.0   1.303538  ...
# 2 2019-07-07 19:00:00  KI  DECEASED  2019      5        0.0   1.303538  ...
# 3 2019-07-07 19:00:00  KI  DECEASED  2019      5        0.0   1.303538  ...
# 4 2019-07-07 19:00:00  KI  DECEASED  2019      5        0.0   1.303538  ...
#
#    RCC_TST3_C  RCC_TST3_R  RCC_TUB_C  RCC_TUB_R  RCC_VAS_C  RCC_VAS_R  \
# ...

# %%
#drop everything except the column names and first row
df_19_col_post = df_19.iloc[[0]]
df_19_col_post.head()
# Out:
#                 ENTIRE_NAME CTR_CD CTR_TY        RELEASE_DATE ORG    D_OR_L  \
# 0  Hartford Hospital (CTHH)   CTHH    TX1 2019-07-07 19:00:00  KI  DECEASED
#
#    YEAR  MONTH  RCC_A10_C  RCC_A10_R  ...  RCC_TST3_C  RCC_TST3_R  RCC_TUB_C  \
# 0  2019      5        0.0   1.303538  ...           -           -   6.818182
#
#    RCC_TUB_R  RCC_VAS_C  RCC_VAS_R  RCC_VHD_C  RCC_VHD_R  RCC_CON_C  RCC_CON_R
# 0   4.655493        0.0    0.18622          -          -        0.0   2.420857
#
# [1 rows x 194 columns]

# %%
#transpose the columns into rows
df_19_col_transp = df_19_col_post.T
df_19_col_transp.head(30)
# Out:
#                                      0
# ENTIRE_NAME   Hartford Hospital (CTHH)
# CTR_CD                            CTHH
# CTR_TY                             TX1
# RELEASE_DATE       2019-07-07 19:00:00
# ORG                                 KI
# D_OR_L                        DECEASED
# YEAR                              2019
# MONTH                                5
# RCC_A10_C                          0.0
# RCC_A10_R                     1.303538
# RCC_A17_C                          0.0
# RCC_A17_R                     1.675978
# RCC_A2_C                           0.0
# RCC_A2_R                      0.372439
# RCC_A34_C                     5.681818
# RCC_A34_R                     9.683426
# RCC_A49_C                         25.0
# RCC_A49_R                    20.856611
# RCC_A64_C                    51.136364
# RCC_A64_R                    43.389199
# RCC_A65P_C                   18.181818
# RCC_A65P_R                   22.718808
# RCC_AU_C                             0
# ...

# %%
#df_19_col_post.to_csv('output/df_19.csv')
df_col_post.to_csv('output/df_15.csv')
df_col.to_csv('output/df_12.csv')

# %%
filepath = 'kidney/csrs_final_tables1207KI.XLS'
sheet_name = 'Table 7 - Living'
df_l = pd.read_excel(filepath, sheet_name)

# %%
#drop everything except the column names and first row
df_col_l = df_l.iloc[[0]]
df_col_l.head()
# Out:
#   Unnamed: 0        CTR_CD        CTR_TY   RELEASE_DATE     ORG  \
# 0    Comment   Center Code   Center Type   Release Date   Organ
#
#                      RCL_A10_C                    RCL_A10_R  \
# 0   Age (Percent)2-10 | center   Age (Percent)2-10 | region
#
#                       RCL_A17_C                     RCL_A17_R  \
# 0   Age (Percent)11-17 | center   Age (Percent)11-17 | region
#
#                     RCL_A2_C  ...  \
# 0   Age (Percent)<2 | center  ...
#
#                                          RCL_TST2A_C  \
# 0   Medical Urgency Status at Transplant (Percent...
#
#                                          RCL_TST2A_R  \
# 0   Medical Urgency Status at Transplant (Percent...
#
#                                          RCL_TST2B_C  \
# 0   Medical Urgency Status at Transplant (Percent...
#
#                                          RCL_TST2B_R  \
# 0   Medical Urgency Status at Transplant (Percent...
#
#                                           RCL_TST3_C  \
# ...

# %%
#transpose the columns into rows
df_col_transp_l = df_col_l.T
df_col_transp_l.head(30)
# Out:
#                                                                0
# Unnamed: 0                                               Comment
#  CTR_CD                                              Center Code
#  CTR_TY                                              Center Type
#  RELEASE_DATE                                       Release Date
#  ORG                                                       Organ
#  RCL_A10_C                            Age (Percent)2-10 | center
#  RCL_A10_R                            Age (Percent)2-10 | region
#  RCL_A17_C                           Age (Percent)11-17 | center
#  RCL_A17_R                           Age (Percent)11-17 | region
#  RCL_A2_C                               Age (Percent)<2 | center
#  RCL_A2_R                               Age (Percent)<2 | region
#  RCL_A34_C                           Age (Percent)18-34 | center
#  RCL_A34_R                           Age (Percent)18-34 | region
# ...

# %%
filepath = 'kidney/csrs_final_tables_2211_KI.xls'
sheet_name = 'Figures C1-C2 - Living'
df_post_l = pd.read_excel(filepath, sheet_name)

# %%
#drop everything except the column names and first row
df_post_col_l = df_post_l.iloc[[0]]
df_post_col_l.head()
# Out:
#    ENTIRE_NAME       CTR_CD       CTR_TY  RELEASE_DATE    ORG RCL_A10_C  \
# 0  Center Name  Center Code  Center Type  Release Date  Organ  Age 2-11
#
#   RCL_A10_R  RCL_A17_C  RCL_A17_R RCL_A2_C  ... RCL_TST2B_C RCL_TST2B_R  \
# 0  Age 2-11  Age 12-17  Age 12-17  Age < 2  ...   Status 2B   Status 2B
#
#   RCL_TST3_C RCL_TST3_R                         RCL_TUB_C  \
# 0   Status 3   Status 3  Tubular and Interstitial Disease
#
#                           RCL_TUB_R                         RCL_VAS_C  \
# 0  Tubular and Interstitial Disease  Renovascular & Vascular Diseases
#
#                           RCL_VAS_R                        RCL_CON_C  \
# 0  Renovascular & Vascular Diseases  Congenital, Familial, Metabolic
#
#                          RCL_CON_R
# 0  Congenital, Familial, Metabolic
#
# [1 rows x 177 columns]

# %%
#transpose the columns into rows
df_post_col_transp_l = df_post_col_l.T
df_post_col_transp_l.head(30)
# Out:
#                             0
# ENTIRE_NAME       Center Name
# CTR_CD            Center Code
# CTR_TY            Center Type
# RELEASE_DATE     Release Date
# ORG                     Organ
# RCL_A10_C            Age 2-11
# RCL_A10_R            Age 2-11
# RCL_A17_C           Age 12-17
# RCL_A17_R           Age 12-17
# RCL_A2_C              Age < 2
# RCL_A2_R              Age < 2
# RCL_A34_C           Age 18-34
# RCL_A34_R           Age 18-34
# RCL_A49_C           Age 35-49
# RCL_A49_R           Age 35-49
# RCL_A64_C           Age 50-64
# RCL_A64_R           Age 50-64
# RCL_A69_C           Age 65-69
# RCL_A69_R           Age 65-69
# RCL_A70P_C            Age 70+
# RCL_A70P_R            Age 70+
# RCL_BAB_C       Blood Type AB
# RCL_BAB_R       Blood Type AB
# RCL_BAT_C     Biliary Atresia
# RCL_BAT_R     Biliary Atresia
# RCL_BA_C         Blood Type A
# RCL_BA_R         Blood Type A
# RCL_BB_C         Blood Type B
# RCL_BB_R         Blood Type B
# RCL_BMI20_C          BMI 0-20

# %%
#send to csv
df_col_transp_l.to_csv('output/df_col_transp_l.csv')
df_post_col_transp_l.to_csv('output/df_post_col_transp_l.csv')
