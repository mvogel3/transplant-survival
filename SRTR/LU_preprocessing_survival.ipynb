# %%
# importing dependencies

import pandas as pd
import os
import re
import calendar
import numpy as np

# %%
excel_files = ['LU-1207.XLS', 'LU-1301.XLS', 'LU-1307.XLS', 'LU-1401.XLS', 'LU-1406.XLS', 'LU-1412.XLS', 
               'LU-1506.XLS', 'LU-1512.XLS', 'LU-1606.XLS', 'LU-1701.xls', 'LU-1707.xls', 'LU-1711.xls', 
               'LU-1808.xls', 'LU-1811.xls', 'LU-1905.xls', 'LU-1911.xls', 'LU-2006.xls', 'LU-2011.xls', 
               'LU-2105.xls', 'LU-2111.xls', 'LU-2205.xls', 'LU-2211.xls']

concat=False;
for file in excel_files:
    year_month = re.sub("[^\d]", "", file)
    year = "20"+year_month[0:2]
    month = int(year_month[2:4])
    
    
    if(year in ["2012", "2013", "2014"]):
        sheet_name = "Table 10"
    elif(year in ['2015', '2016', '2017', '2018', '2019', '2020', '2021']):
        sheet_name = "TablesC5-C10 FiguresC1-C12"
    else:
        sheet_name = "TablesC5-C12 Figures C1-C20"
        
    
    survival_df = pd.read_excel(io='Resources_LU/'+file, sheet_name=sheet_name)

        
    if(len(survival_df.index)>0):
        survival_df = survival_df.drop(survival_df.index[0])
   
        
    survival_df_cleaned = pd.DataFrame()
    
    
    
    columns_to_keep = ["Unnamed: 0", ' ctr_cd', 'ctr_ty', 'ENTIRE_NAME', 'CTR_CD', 'CTR_TY', 'RELEASE_DATE', 'ORG', 
                       'GSR_AD_OBS_C1M', 'GSR_AD_OBS_C1Y', 'GSR_AD_OBS_C3Y', 
                       'GSR_AD_ACT_C1M', 'GSR_AD_ACT_C1Y', 'GSR_AD_ACT_C3Y', 
                       'GSR_AD_ADJ_C1M', 'GSR_AD_ADJ_C1Y', 'GSR_AD_ADJ_C3Y',
                       'GSR_AD_EXP_C1M', 'GSR_AD_EXP_C1Y', 'GSR_AD_EXP_C3Y', 
                       'GSR_AD_N_C1M', 'GSR_AD_N_C1Y', 'GSR_AD_N_C3Y', 
                       'GSR_P0_OBS_C1M', 'GSR_P0_OBS_C1Y', 'GSR_P0_OBS_C3Y',
                       'GSR_P0_ACT_C1M', 'GSR_P0_ACT_C1Y', 'GSR_P0_ACT_C3Y', 
                       'GSR_P0_ADJ_C1M', 'GSR_P0_ADJ_C1Y', 'GSR_P0_ADJ_C3Y',
                       'GSR_P0_EXP_C1M', 'GSR_P0_EXP_C1Y', 'GSR_P0_EXP_C3Y', 
                       'GSR_P0_N_C1M', 'GSR_P0_N_C1Y', 'GSR_P0_C3Y']
    
    for column in columns_to_keep:
        if column in survival_df:
            survival_df_cleaned[column]=survival_df[column]
        elif column+" " in survival_df:
            survival_df_cleaned[column]=survival_df[column+" "]
        elif " "+column in survival_df:
            survival_df_cleaned[column]=survival_df[" "+column]
        elif " "+column+" " in survival_df:
            survival_df_cleaned[column]=survival_df[" "+column+" "]

    
    survival_df_cleaned["YEAR"]=year
    survival_df_cleaned["MONTH"]=month

    if(concat==True):
        merged_survival_df= pd.concat([merged_survival_df, survival_df_cleaned], axis=0)

    else:
        merged_survival_df=survival_df_cleaned
        
        concat=True

# %%
merged_survival_df
# Out:
#                                            Unnamed: 0  ctr_cd ctr_ty  \
# 1              University of Alabama Hospital (ALUA)    ALUA    TX1
# 2    St. Joseph's Hospital and Medical Center (AZSJ)    AZSJ    TX1
# 3   University Medical Center, Univ of Arizona (AZ...   AZUA    TX1
# 4              Childrens Hospital Los Angeles (CACL)    CACL    TX1
# 5                 Cedars-Sinai Medical Center (CACS)    CACS    TX1
# ..                                                ...     ...    ...
# 67                                                NaN     NaN    NaN
# 68                                                NaN     NaN    NaN
# 69                                                NaN     NaN    NaN
# 70                                                NaN     NaN    NaN
# 71                                                NaN     NaN    NaN
#
#            RELEASE_DATE     ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1           2012/07/13    Lung              3              8             26
# 2           2012/07/13    Lung              2              9              5
# 3           2012/07/13    Lung              1              7             18
# 4           2012/07/13    Lung              0              1              1
# 5           2012/07/13    Lung              0              4             24
# ..                  ...     ...            ...            ...            ...
# 67  2023-01-05 18:00:00      LU              0              4             14
# 68  2023-01-05 18:00:00      LU              3              3             17
# 69  2023-01-05 18:00:00      LU              3             10             15
# 70  2023-01-05 18:00:00      LU              0              0              8
# 71  2023-01-05 18:00:00      LU              1              4             15
#
#    GSR_AD_ACT_C1M GSR_AD_ACT_C1Y  ... GSR_P0_EXP_C1M GSR_P0_EXP_C1Y  \
# 1           91.89           77.4  ...
# 2           96.92           83.1  ...
# 3           97.37           80.7  ...
# 4             100             50  ...
# 5             100          89.89  ...
# ..            ...            ...  ...            ...            ...
# 67            100      90.573339  ...        0.04019       0.068767
# 68      94.609164      94.609164  ...            NaN            NaN
# 69      97.680288      90.037094  ...        0.04019       0.068767
# 70            100            100  ...            NaN            NaN
# 71      98.648649       93.00818  ...        0.04019       0.068767
#
#    GSR_P0_EXP_C3Y GSR_P0_N_C1M GSR_P0_N_C1Y  YEAR MONTH CTR_CD CTR_TY  \
# 1                           2            2   2012     7    NaN    NaN
# 2                           2            2   2012     7    NaN    NaN
# 3                                            2012     7    NaN    NaN
# 4                           3            3   2012     7    NaN    NaN
# 5                                            2012     7    NaN    NaN
# ..            ...          ...          ...   ...   ...    ...    ...
# 67            NaN            1            1  2022    11   VAFH    TX1
# 68            NaN          NaN          NaN  2022    11   VAUV    TX1
# 69       0.121707            1            1  2022    11   WAUW    TX1
# 70            NaN          NaN          NaN  2022    11   WISE    TX1
# 71       0.189194            1            1  2022    11   WIUW    TX1
#
#                                           ENTIRE_NAME
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# ..                                                ...
# 67                      Inova Fairfax Hospital (VAFH)
# 68  University of Virginia Health Sciences Center ...
# 69     University of Washington Medical Center (WAUW)
# 70        Froedtert Memorial Lutheran Hospital (WISE)
# 71  University of Wisconsin Hospital and Clinics (...
#
# [1573 rows x 39 columns]

# %%
column_adding = merged_survival_df.copy()

# df['b'] = df['b'].fillna(df['a'])

column_adding['ENTIRE_NAME'] = column_adding['ENTIRE_NAME'].fillna(column_adding['Unnamed: 0'])

# column_adding['ENTIRE_NAME'] = column_adding['ENTIRE_NAME'] + column_adding['Unnamed: 0']

column_adding
# Out:
#                                            Unnamed: 0  ctr_cd ctr_ty  \
# 1              University of Alabama Hospital (ALUA)    ALUA    TX1
# 2    St. Joseph's Hospital and Medical Center (AZSJ)    AZSJ    TX1
# 3   University Medical Center, Univ of Arizona (AZ...   AZUA    TX1
# 4              Childrens Hospital Los Angeles (CACL)    CACL    TX1
# 5                 Cedars-Sinai Medical Center (CACS)    CACS    TX1
# ..                                                ...     ...    ...
# 67                                                NaN     NaN    NaN
# 68                                                NaN     NaN    NaN
# 69                                                NaN     NaN    NaN
# 70                                                NaN     NaN    NaN
# 71                                                NaN     NaN    NaN
#
#            RELEASE_DATE     ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1           2012/07/13    Lung              3              8             26
# 2           2012/07/13    Lung              2              9              5
# 3           2012/07/13    Lung              1              7             18
# 4           2012/07/13    Lung              0              1              1
# 5           2012/07/13    Lung              0              4             24
# ..                  ...     ...            ...            ...            ...
# 67  2023-01-05 18:00:00      LU              0              4             14
# 68  2023-01-05 18:00:00      LU              3              3             17
# 69  2023-01-05 18:00:00      LU              3             10             15
# 70  2023-01-05 18:00:00      LU              0              0              8
# 71  2023-01-05 18:00:00      LU              1              4             15
#
#    GSR_AD_ACT_C1M GSR_AD_ACT_C1Y  ... GSR_P0_EXP_C1M GSR_P0_EXP_C1Y  \
# 1           91.89           77.4  ...
# 2           96.92           83.1  ...
# 3           97.37           80.7  ...
# 4             100             50  ...
# 5             100          89.89  ...
# ..            ...            ...  ...            ...            ...
# 67            100      90.573339  ...        0.04019       0.068767
# 68      94.609164      94.609164  ...            NaN            NaN
# 69      97.680288      90.037094  ...        0.04019       0.068767
# 70            100            100  ...            NaN            NaN
# 71      98.648649       93.00818  ...        0.04019       0.068767
#
#    GSR_P0_EXP_C3Y GSR_P0_N_C1M GSR_P0_N_C1Y  YEAR MONTH CTR_CD CTR_TY  \
# 1                           2            2   2012     7    NaN    NaN
# 2                           2            2   2012     7    NaN    NaN
# 3                                            2012     7    NaN    NaN
# 4                           3            3   2012     7    NaN    NaN
# 5                                            2012     7    NaN    NaN
# ..            ...          ...          ...   ...   ...    ...    ...
# 67            NaN            1            1  2022    11   VAFH    TX1
# 68            NaN          NaN          NaN  2022    11   VAUV    TX1
# 69       0.121707            1            1  2022    11   WAUW    TX1
# 70            NaN          NaN          NaN  2022    11   WISE    TX1
# 71       0.189194            1            1  2022    11   WIUW    TX1
#
#                                           ENTIRE_NAME
# 1              University of Alabama Hospital (ALUA)
# 2    St. Joseph's Hospital and Medical Center (AZSJ)
# 3   University Medical Center, Univ of Arizona (AZ...
# 4              Childrens Hospital Los Angeles (CACL)
# 5                 Cedars-Sinai Medical Center (CACS)
# ..                                                ...
# 67                      Inova Fairfax Hospital (VAFH)
# 68  University of Virginia Health Sciences Center ...
# 69     University of Washington Medical Center (WAUW)
# 70        Froedtert Memorial Lutheran Hospital (WISE)
# 71  University of Wisconsin Hospital and Clinics (...
#
# [1573 rows x 39 columns]

# %%
column_adding['YEAR'].unique()
# Out:
# array(['2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020', '2021', '2022'], dtype=object)

# %%
# df.loc[df['column_name'].isin(some_values)]

column_adding.loc[column_adding['YEAR']=='2012']
# Out:
#                                            Unnamed: 0  ctr_cd ctr_ty  \
# 1              University of Alabama Hospital (ALUA)    ALUA    TX1
# 2    St. Joseph's Hospital and Medical Center (AZSJ)    AZSJ    TX1
# 3   University Medical Center, Univ of Arizona (AZ...   AZUA    TX1
# 4              Childrens Hospital Los Angeles (CACL)    CACL    TX1
# 5                 Cedars-Sinai Medical Center (CACS)    CACS    TX1
# ..                                                ...     ...    ...
# 65    University of Washington Medical Center (WAUW)    WAUW    TX1
# 66           Children's Hospital of Wisconsin (WICH)    WICH    TX1
# 67       Froedtert Memorial Lutheran Hospital (WISE)    WISE    TX1
# 68           Aurora St. Luke's Medical Center (WISL)    WISL    TX1
# 69  University of Wisconsin Hospital and Clinics (...   WIUW    TX1
#
#     RELEASE_DATE     ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1    2012/07/13    Lung              3              8             26
# 2    2012/07/13    Lung              2              9              5
# 3    2012/07/13    Lung              1              7             18
# 4    2012/07/13    Lung              0              1              1
# 5    2012/07/13    Lung              0              4             24
# ..           ...     ...            ...            ...            ...
# 65   2012/07/13    Lung              6             19             29
# 66   2012/07/13    Lung
# 67   2012/07/13    Lung              0              0              3
# 68   2012/07/13    Lung              1              7              8
# 69   2012/07/13    Lung              3             17             23
#
#    GSR_AD_ACT_C1M GSR_AD_ACT_C1Y  ... GSR_P0_EXP_C1M GSR_P0_EXP_C1Y  \
# 1           91.89           77.4  ...
# 2           96.92           83.1  ...
# 3           97.37           80.7  ...
# 4             100             50  ...
# 5             100          89.89  ...
# ..            ...            ...  ...            ...            ...
# 65          95.04          83.73  ...
# 66                                ...
# 67            100            100  ...
# 68          94.12           54.9  ...
# 69          96.67           80.9  ...
#
#    GSR_P0_EXP_C3Y GSR_P0_N_C1M GSR_P0_N_C1Y  YEAR MONTH CTR_CD CTR_TY  \
# 1                           2            2   2012     7    NaN    NaN
# 2                           2            2   2012     7    NaN    NaN
# 3                                            2012     7    NaN    NaN
# 4                           3            3   2012     7    NaN    NaN
# 5                                            2012     7    NaN    NaN
# ..            ...          ...          ...   ...   ...    ...    ...
# 65                          1            1   2012     7    NaN    NaN
# 66                                           2012     7    NaN    NaN
# 67                          1            1   2012     7    NaN    NaN
# 68                                           2012     7    NaN    NaN
# 69                          1            1   2012     7    NaN    NaN
#
#                                           ENTIRE_NAME
# 1              University of Alabama Hospital (ALUA)
# 2    St. Joseph's Hospital and Medical Center (AZSJ)
# 3   University Medical Center, Univ of Arizona (AZ...
# 4              Childrens Hospital Los Angeles (CACL)
# 5                 Cedars-Sinai Medical Center (CACS)
# ..                                                ...
# 65    University of Washington Medical Center (WAUW)
# 66           Children's Hospital of Wisconsin (WICH)
# 67       Froedtert Memorial Lutheran Hospital (WISE)
# 68           Aurora St. Luke's Medical Center (WISL)
# 69  University of Wisconsin Hospital and Clinics (...
#
# [69 rows x 39 columns]

# %%
column_adding.columns
# Out:
# Index(['Unnamed: 0', ' ctr_cd', 'ctr_ty', 'RELEASE_DATE', 'ORG',
#        'GSR_AD_OBS_C1M', 'GSR_AD_OBS_C1Y', 'GSR_AD_OBS_C3Y', 'GSR_AD_ACT_C1M',
#        'GSR_AD_ACT_C1Y', 'GSR_AD_ACT_C3Y', 'GSR_AD_ADJ_C1M', 'GSR_AD_ADJ_C1Y',
#        'GSR_AD_ADJ_C3Y', 'GSR_AD_EXP_C1M', 'GSR_AD_EXP_C1Y', 'GSR_AD_EXP_C3Y',
#        'GSR_AD_N_C1M', 'GSR_AD_N_C1Y', 'GSR_AD_N_C3Y', 'GSR_P0_OBS_C1M',
#        'GSR_P0_OBS_C1Y', 'GSR_P0_OBS_C3Y', 'GSR_P0_ACT_C1M', 'GSR_P0_ACT_C1Y',
#        'GSR_P0_ACT_C3Y', 'GSR_P0_ADJ_C1M', 'GSR_P0_ADJ_C1Y', 'GSR_P0_ADJ_C3Y',
#        'GSR_P0_EXP_C1M', 'GSR_P0_EXP_C1Y', 'GSR_P0_EXP_C3Y', 'GSR_P0_N_C1M',
#        'GSR_P0_N_C1Y', 'YEAR', 'MONTH', 'CTR_CD', 'CTR_TY', 'ENTIRE_NAME'],
#       dtype='object')

# %%
# column_adding['ENTIRE_NAME'] = column_adding['ENTIRE_NAME'].fillna(column_adding['Unnamed: 0'])
column_adding['CTR_CD'] = column_adding['CTR_CD'].fillna(column_adding[' ctr_cd'])
column_adding['CTR_TY'] = column_adding['CTR_TY'].fillna(column_adding['ctr_ty'])

column_adding
# Out:
#                                            Unnamed: 0  ctr_cd ctr_ty  \
# 1              University of Alabama Hospital (ALUA)    ALUA    TX1
# 2    St. Joseph's Hospital and Medical Center (AZSJ)    AZSJ    TX1
# 3   University Medical Center, Univ of Arizona (AZ...   AZUA    TX1
# 4              Childrens Hospital Los Angeles (CACL)    CACL    TX1
# 5                 Cedars-Sinai Medical Center (CACS)    CACS    TX1
# ..                                                ...     ...    ...
# 67                                                NaN     NaN    NaN
# 68                                                NaN     NaN    NaN
# 69                                                NaN     NaN    NaN
# 70                                                NaN     NaN    NaN
# 71                                                NaN     NaN    NaN
#
#            RELEASE_DATE     ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1           2012/07/13    Lung              3              8             26
# 2           2012/07/13    Lung              2              9              5
# 3           2012/07/13    Lung              1              7             18
# 4           2012/07/13    Lung              0              1              1
# 5           2012/07/13    Lung              0              4             24
# ..                  ...     ...            ...            ...            ...
# 67  2023-01-05 18:00:00      LU              0              4             14
# 68  2023-01-05 18:00:00      LU              3              3             17
# 69  2023-01-05 18:00:00      LU              3             10             15
# 70  2023-01-05 18:00:00      LU              0              0              8
# 71  2023-01-05 18:00:00      LU              1              4             15
#
#    GSR_AD_ACT_C1M GSR_AD_ACT_C1Y  ... GSR_P0_EXP_C1M GSR_P0_EXP_C1Y  \
# 1           91.89           77.4  ...
# 2           96.92           83.1  ...
# 3           97.37           80.7  ...
# 4             100             50  ...
# 5             100          89.89  ...
# ..            ...            ...  ...            ...            ...
# 67            100      90.573339  ...        0.04019       0.068767
# 68      94.609164      94.609164  ...            NaN            NaN
# 69      97.680288      90.037094  ...        0.04019       0.068767
# 70            100            100  ...            NaN            NaN
# 71      98.648649       93.00818  ...        0.04019       0.068767
#
#    GSR_P0_EXP_C3Y GSR_P0_N_C1M GSR_P0_N_C1Y  YEAR MONTH  CTR_CD CTR_TY  \
# 1                           2            2   2012     7   ALUA    TX1
# 2                           2            2   2012     7   AZSJ    TX1
# 3                                            2012     7   AZUA    TX1
# 4                           3            3   2012     7   CACL    TX1
# 5                                            2012     7   CACS    TX1
# ..            ...          ...          ...   ...   ...     ...    ...
# 67            NaN            1            1  2022    11    VAFH    TX1
# 68            NaN          NaN          NaN  2022    11    VAUV    TX1
# 69       0.121707            1            1  2022    11    WAUW    TX1
# 70            NaN          NaN          NaN  2022    11    WISE    TX1
# 71       0.189194            1            1  2022    11    WIUW    TX1
#
#                                           ENTIRE_NAME
# 1              University of Alabama Hospital (ALUA)
# 2    St. Joseph's Hospital and Medical Center (AZSJ)
# 3   University Medical Center, Univ of Arizona (AZ...
# 4              Childrens Hospital Los Angeles (CACL)
# 5                 Cedars-Sinai Medical Center (CACS)
# ..                                                ...
# 67                      Inova Fairfax Hospital (VAFH)
# 68  University of Virginia Health Sciences Center ...
# 69     University of Washington Medical Center (WAUW)
# 70        Froedtert Memorial Lutheran Hospital (WISE)
# 71  University of Wisconsin Hospital and Clinics (...
#
# [1573 rows x 39 columns]

# %%
column_adding.loc[column_adding['YEAR']=='2021']
# Out:
#    Unnamed: 0  ctr_cd ctr_ty         RELEASE_DATE ORG GSR_AD_OBS_C1M  \
# 1         NaN     NaN    NaN  2021-07-06 19:00:00  LU              0
# 2         NaN     NaN    NaN  2021-07-06 19:00:00  LU            NaN
# 3         NaN     NaN    NaN  2021-07-06 19:00:00  LU              2
# 4         NaN     NaN    NaN  2021-07-06 19:00:00  LU              0
# 5         NaN     NaN    NaN  2021-07-06 19:00:00  LU              3
# ..        ...     ...    ...                  ...  ..            ...
# 68        NaN     NaN    NaN  2022-01-06 18:00:00  LU              1
# 69        NaN     NaN    NaN  2022-01-06 18:00:00  LU              1
# 70        NaN     NaN    NaN  2022-01-06 18:00:00  LU              3
# 71        NaN     NaN    NaN  2022-01-06 18:00:00  LU              1
# 72        NaN     NaN    NaN  2022-01-06 18:00:00  LU              2
#
#    GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y GSR_AD_ACT_C1M GSR_AD_ACT_C1Y  ...  \
# 1               5             13            100      80.519809  ...
# 2             NaN              3            NaN            NaN  ...
# 3              11             56      99.198348      94.492317  ...
# 4               9             18            100      86.989494  ...
# 5               9             14      92.682927      72.816159  ...
# ..            ...            ...            ...            ...  ...
# 68              3             15      98.550725      95.237623  ...
# 69              5             18      98.333333      89.350962  ...
# 70              8             20      97.625197      92.460275  ...
# 71              3              6      91.666667             75  ...
# 72              7             10      97.333333       87.98275  ...
#
#    GSR_P0_EXP_C1M GSR_P0_EXP_C1Y GSR_P0_EXP_C3Y GSR_P0_N_C1M GSR_P0_N_C1Y  \
# 1             NaN            NaN        0.23968          NaN          NaN
# 2             NaN            NaN            NaN          NaN          NaN
# 3        0.010638        0.08688       0.997059            1            1
# 4             NaN            NaN            NaN          NaN          NaN
# 5             NaN            NaN            NaN          NaN          NaN
# ..            ...            ...            ...          ...          ...
# 68       0.011236       0.034495            NaN            1            1
# 69            NaN            NaN       0.474804          NaN          NaN
# 70       0.022472       0.167161            NaN            2            2
# 71            NaN            NaN            NaN          NaN          NaN
# 72       0.022472       0.265333            NaN            2            2
#
#     YEAR MONTH CTR_CD CTR_TY  \
# 1   2021     5   ALUA    TX1
# 2   2021     5   AZMC    TX1
# 3   2021     5   AZSJ    TX1
# 4   2021     5   AZUA    TX1
# 5   2021     5   CACS    TX1
# ..   ...   ...    ...    ...
# 68  2021    11   VAFH    TX1
# 69  2021    11   VAUV    TX1
# 70  2021    11   WAUW    TX1
# 71  2021    11   WISE    TX1
# 72  2021    11   WIUW    TX1
#
#                                           ENTIRE_NAME
# 1               University of Alabama Hospital (ALUA)
# 2                         Mayo Clinic Hospital (AZMC)
# 3     St. Joseph's Hospital and Medical Center (AZSJ)
# 4      Banner University Medical Center-Tucson (AZUA)
# 5                  Cedars-Sinai Medical Center (CACS)
# ..                                                ...
# 68                      Inova Fairfax Hospital (VAFH)
# 69  University of Virginia Health Sciences Center ...
# 70     University of Washington Medical Center (WAUW)
# 71        Froedtert Memorial Lutheran Hospital (WISE)
# 72  University of Wisconsin Hospital and Clinics (...
#
# [144 rows x 39 columns]

# %%
survival_final = column_adding.drop(columns=['Unnamed: 0', ' ctr_cd', 'ctr_ty'])

survival_final
# Out:
#            RELEASE_DATE     ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1           2012/07/13    Lung              3              8             26
# 2           2012/07/13    Lung              2              9              5
# 3           2012/07/13    Lung              1              7             18
# 4           2012/07/13    Lung              0              1              1
# 5           2012/07/13    Lung              0              4             24
# ..                  ...     ...            ...            ...            ...
# 67  2023-01-05 18:00:00      LU              0              4             14
# 68  2023-01-05 18:00:00      LU              3              3             17
# 69  2023-01-05 18:00:00      LU              3             10             15
# 70  2023-01-05 18:00:00      LU              0              0              8
# 71  2023-01-05 18:00:00      LU              1              4             15
#
#    GSR_AD_ACT_C1M GSR_AD_ACT_C1Y GSR_AD_ACT_C3Y GSR_AD_ADJ_C1M GSR_AD_ADJ_C1Y  \
# 1           91.89           77.4         61.38          95.46          83.64
# 2           96.92           83.1         76.19          95.49          83.62
# 3           97.37           80.7         57.84          95.15          82.75
# 4             100             50         50.00          97.39          90.05
# 5             100          89.89         47.83          94.75          82.14
# ..            ...            ...            ...            ...            ...
# 67            100      90.573339      67.974985      97.734159       87.00692
# 68      94.609164      94.609164      67.822527      97.708498      86.879285
# 69      97.680288      90.037094      85.455163      98.056321      88.737852
# 70            100            100      65.185185      97.989644      88.364587
# 71      98.648649       93.00818      68.742678      97.985884      88.350936
#
#     ... GSR_P0_EXP_C1M GSR_P0_EXP_C1Y GSR_P0_EXP_C3Y GSR_P0_N_C1M  \
# 1   ...                                                        2
# 2   ...                                                        2
# 3   ...
# 4   ...                                                        3
# 5   ...
# ..  ...            ...            ...            ...          ...
# 67  ...        0.04019       0.068767            NaN            1
# 68  ...            NaN            NaN            NaN          NaN
# 69  ...        0.04019       0.068767       0.121707            1
# 70  ...            NaN            NaN            NaN          NaN
# 71  ...        0.04019       0.068767       0.189194            1
#
#    GSR_P0_N_C1Y  YEAR MONTH  CTR_CD CTR_TY  \
# 1            2   2012     7   ALUA    TX1
# 2            2   2012     7   AZSJ    TX1
# 3                2012     7   AZUA    TX1
# 4            3   2012     7   CACL    TX1
# 5                2012     7   CACS    TX1
# ..          ...   ...   ...     ...    ...
# 67            1  2022    11    VAFH    TX1
# 68          NaN  2022    11    VAUV    TX1
# 69            1  2022    11    WAUW    TX1
# 70          NaN  2022    11    WISE    TX1
# 71            1  2022    11    WIUW    TX1
#
#                                           ENTIRE_NAME
# 1              University of Alabama Hospital (ALUA)
# 2    St. Joseph's Hospital and Medical Center (AZSJ)
# 3   University Medical Center, Univ of Arizona (AZ...
# 4              Childrens Hospital Los Angeles (CACL)
# 5                 Cedars-Sinai Medical Center (CACS)
# ..                                                ...
# 67                      Inova Fairfax Hospital (VAFH)
# 68  University of Virginia Health Sciences Center ...
# 69     University of Washington Medical Center (WAUW)
# 70        Froedtert Memorial Lutheran Hospital (WISE)
# 71  University of Wisconsin Hospital and Clinics (...
#
# [1573 rows x 36 columns]

# %%
first_column = survival_final.pop('ENTIRE_NAME')
second_column = survival_final.pop('CTR_CD')
third_column = survival_final.pop('CTR_TY')

survival_final.insert(0, 'ENTIRE_NAME', first_column)
survival_final.insert(1, 'CTR_CD', second_column)
survival_final.insert(2, 'CTR_TY', third_column)

survival_final
# Out:
#                                           ENTIRE_NAME  CTR_CD CTR_TY  \
# 1              University of Alabama Hospital (ALUA)    ALUA    TX1
# 2    St. Joseph's Hospital and Medical Center (AZSJ)    AZSJ    TX1
# 3   University Medical Center, Univ of Arizona (AZ...   AZUA    TX1
# 4              Childrens Hospital Los Angeles (CACL)    CACL    TX1
# 5                 Cedars-Sinai Medical Center (CACS)    CACS    TX1
# ..                                                ...     ...    ...
# 67                      Inova Fairfax Hospital (VAFH)    VAFH    TX1
# 68  University of Virginia Health Sciences Center ...    VAUV    TX1
# 69     University of Washington Medical Center (WAUW)    WAUW    TX1
# 70        Froedtert Memorial Lutheran Hospital (WISE)    WISE    TX1
# 71  University of Wisconsin Hospital and Clinics (...    WIUW    TX1
#
#            RELEASE_DATE     ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1           2012/07/13    Lung              3              8             26
# 2           2012/07/13    Lung              2              9              5
# 3           2012/07/13    Lung              1              7             18
# 4           2012/07/13    Lung              0              1              1
# 5           2012/07/13    Lung              0              4             24
# ..                  ...     ...            ...            ...            ...
# 67  2023-01-05 18:00:00      LU              0              4             14
# 68  2023-01-05 18:00:00      LU              3              3             17
# 69  2023-01-05 18:00:00      LU              3             10             15
# 70  2023-01-05 18:00:00      LU              0              0              8
# 71  2023-01-05 18:00:00      LU              1              4             15
#
#    GSR_AD_ACT_C1M GSR_AD_ACT_C1Y  ... GSR_P0_ADJ_C1M GSR_P0_ADJ_C1Y  \
# 1           91.89           77.4  ...
# 2           96.92           83.1  ...
# 3           97.37           80.7  ...
# 4             100             50  ...
# 5             100          89.89  ...
# ..            ...            ...  ...            ...            ...
# 67            100      90.573339  ...      96.060704      93.354406
# 68      94.609164      94.609164  ...            NaN            NaN
# 69      97.680288      90.037094  ...      96.060704      93.354406
# 70            100            100  ...            NaN            NaN
# 71      98.648649       93.00818  ...      96.060704      93.354406
#
#    GSR_P0_ADJ_C3Y GSR_P0_EXP_C1M GSR_P0_EXP_C1Y GSR_P0_EXP_C3Y GSR_P0_N_C1M  \
# 1                                                                        2
# 2                                                                        2
# 3
# 4                                                                        3
# 5
# ..            ...            ...            ...            ...          ...
# 67            NaN        0.04019       0.068767            NaN            1
# 68            NaN            NaN            NaN            NaN          NaN
# 69      56.199068        0.04019       0.068767       0.121707            1
# 70            NaN            NaN            NaN            NaN          NaN
# 71      56.199068        0.04019       0.068767       0.189194            1
#
#    GSR_P0_N_C1Y  YEAR MONTH
# 1            2   2012     7
# 2            2   2012     7
# 3                2012     7
# 4            3   2012     7
# 5                2012     7
# ..          ...   ...   ...
# 67            1  2022    11
# 68          NaN  2022    11
# 69            1  2022    11
# 70          NaN  2022    11
# 71            1  2022    11
#
# [1573 rows x 36 columns]

# %%
survival_final = survival_final.replace(r'^\s*$', np.nan, regex=True)

survival_final
# Out:
#                                           ENTIRE_NAME  CTR_CD CTR_TY  \
# 1              University of Alabama Hospital (ALUA)    ALUA    TX1
# 2    St. Joseph's Hospital and Medical Center (AZSJ)    AZSJ    TX1
# 3   University Medical Center, Univ of Arizona (AZ...   AZUA    TX1
# 4              Childrens Hospital Los Angeles (CACL)    CACL    TX1
# 5                 Cedars-Sinai Medical Center (CACS)    CACS    TX1
# ..                                                ...     ...    ...
# 67                      Inova Fairfax Hospital (VAFH)    VAFH    TX1
# 68  University of Virginia Health Sciences Center ...    VAUV    TX1
# 69     University of Washington Medical Center (WAUW)    WAUW    TX1
# 70        Froedtert Memorial Lutheran Hospital (WISE)    WISE    TX1
# 71  University of Wisconsin Hospital and Clinics (...    WIUW    TX1
#
#            RELEASE_DATE     ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1           2012/07/13    Lung              3              8             26
# 2           2012/07/13    Lung              2              9              5
# 3           2012/07/13    Lung              1              7             18
# 4           2012/07/13    Lung              0              1              1
# 5           2012/07/13    Lung              0              4             24
# ..                  ...     ...            ...            ...            ...
# 67  2023-01-05 18:00:00      LU              0              4             14
# 68  2023-01-05 18:00:00      LU              3              3             17
# 69  2023-01-05 18:00:00      LU              3             10             15
# 70  2023-01-05 18:00:00      LU              0              0              8
# 71  2023-01-05 18:00:00      LU              1              4             15
#
#    GSR_AD_ACT_C1M GSR_AD_ACT_C1Y  ... GSR_P0_ADJ_C1M GSR_P0_ADJ_C1Y  \
# 1           91.89           77.4  ...            NaN            NaN
# 2           96.92           83.1  ...            NaN            NaN
# 3           97.37           80.7  ...            NaN            NaN
# 4             100             50  ...            NaN            NaN
# 5             100          89.89  ...            NaN            NaN
# ..            ...            ...  ...            ...            ...
# 67            100      90.573339  ...      96.060704      93.354406
# 68      94.609164      94.609164  ...            NaN            NaN
# 69      97.680288      90.037094  ...      96.060704      93.354406
# 70            100            100  ...            NaN            NaN
# 71      98.648649       93.00818  ...      96.060704      93.354406
#
#    GSR_P0_ADJ_C3Y GSR_P0_EXP_C1M GSR_P0_EXP_C1Y GSR_P0_EXP_C3Y GSR_P0_N_C1M  \
# 1             NaN            NaN            NaN            NaN           2
# 2             NaN            NaN            NaN            NaN           2
# 3             NaN            NaN            NaN            NaN          NaN
# 4             NaN            NaN            NaN            NaN           3
# 5             NaN            NaN            NaN            NaN          NaN
# ..            ...            ...            ...            ...          ...
# 67            NaN        0.04019       0.068767            NaN            1
# 68            NaN            NaN            NaN            NaN          NaN
# 69      56.199068        0.04019       0.068767       0.121707            1
# 70            NaN            NaN            NaN            NaN          NaN
# 71      56.199068        0.04019       0.068767       0.189194            1
#
#    GSR_P0_N_C1Y  YEAR MONTH
# 1            2   2012     7
# 2            2   2012     7
# 3           NaN  2012     7
# 4            3   2012     7
# 5           NaN  2012     7
# ..          ...   ...   ...
# 67            1  2022    11
# 68          NaN  2022    11
# 69            1  2022    11
# 70          NaN  2022    11
# 71            1  2022    11
#
# [1573 rows x 36 columns]

# %%
survival_final = survival_final.fillna(0)

survival_final
# Out:
#                                           ENTIRE_NAME  CTR_CD CTR_TY  \
# 1              University of Alabama Hospital (ALUA)    ALUA    TX1
# 2    St. Joseph's Hospital and Medical Center (AZSJ)    AZSJ    TX1
# 3   University Medical Center, Univ of Arizona (AZ...   AZUA    TX1
# 4              Childrens Hospital Los Angeles (CACL)    CACL    TX1
# 5                 Cedars-Sinai Medical Center (CACS)    CACS    TX1
# ..                                                ...     ...    ...
# 67                      Inova Fairfax Hospital (VAFH)    VAFH    TX1
# 68  University of Virginia Health Sciences Center ...    VAUV    TX1
# 69     University of Washington Medical Center (WAUW)    WAUW    TX1
# 70        Froedtert Memorial Lutheran Hospital (WISE)    WISE    TX1
# 71  University of Wisconsin Hospital and Clinics (...    WIUW    TX1
#
#            RELEASE_DATE     ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1           2012/07/13    Lung              3              8             26
# 2           2012/07/13    Lung              2              9              5
# 3           2012/07/13    Lung              1              7             18
# 4           2012/07/13    Lung              0              1              1
# 5           2012/07/13    Lung              0              4             24
# ..                  ...     ...            ...            ...            ...
# 67  2023-01-05 18:00:00      LU              0              4             14
# 68  2023-01-05 18:00:00      LU              3              3             17
# 69  2023-01-05 18:00:00      LU              3             10             15
# 70  2023-01-05 18:00:00      LU              0              0              8
# 71  2023-01-05 18:00:00      LU              1              4             15
#
#    GSR_AD_ACT_C1M GSR_AD_ACT_C1Y  ... GSR_P0_ADJ_C1M GSR_P0_ADJ_C1Y  \
# 1           91.89           77.4  ...              0              0
# 2           96.92           83.1  ...              0              0
# 3           97.37           80.7  ...              0              0
# 4             100             50  ...              0              0
# 5             100          89.89  ...              0              0
# ..            ...            ...  ...            ...            ...
# 67            100      90.573339  ...      96.060704      93.354406
# 68      94.609164      94.609164  ...              0              0
# 69      97.680288      90.037094  ...      96.060704      93.354406
# 70            100            100  ...              0              0
# 71      98.648649       93.00818  ...      96.060704      93.354406
#
#    GSR_P0_ADJ_C3Y GSR_P0_EXP_C1M GSR_P0_EXP_C1Y GSR_P0_EXP_C3Y GSR_P0_N_C1M  \
# 1               0              0              0              0           2
# 2               0              0              0              0           2
# 3               0              0              0              0            0
# 4               0              0              0              0           3
# 5               0              0              0              0            0
# ..            ...            ...            ...            ...          ...
# 67              0        0.04019       0.068767              0            1
# 68              0              0              0              0            0
# 69      56.199068        0.04019       0.068767       0.121707            1
# 70              0              0              0              0            0
# 71      56.199068        0.04019       0.068767       0.189194            1
#
#    GSR_P0_N_C1Y  YEAR MONTH
# 1            2   2012     7
# 2            2   2012     7
# 3             0  2012     7
# 4            3   2012     7
# 5             0  2012     7
# ..          ...   ...   ...
# 67            1  2022    11
# 68            0  2022    11
# 69            1  2022    11
# 70            0  2022    11
# 71            1  2022    11
#
# [1573 rows x 36 columns]

# %%
final_df = survival_final.copy()
final_df
# Out:
#                                           ENTIRE_NAME  CTR_CD CTR_TY  \
# 1              University of Alabama Hospital (ALUA)    ALUA    TX1
# 2    St. Joseph's Hospital and Medical Center (AZSJ)    AZSJ    TX1
# 3   University Medical Center, Univ of Arizona (AZ...   AZUA    TX1
# 4              Childrens Hospital Los Angeles (CACL)    CACL    TX1
# 5                 Cedars-Sinai Medical Center (CACS)    CACS    TX1
# ..                                                ...     ...    ...
# 67                      Inova Fairfax Hospital (VAFH)    VAFH    TX1
# 68  University of Virginia Health Sciences Center ...    VAUV    TX1
# 69     University of Washington Medical Center (WAUW)    WAUW    TX1
# 70        Froedtert Memorial Lutheran Hospital (WISE)    WISE    TX1
# 71  University of Wisconsin Hospital and Clinics (...    WIUW    TX1
#
#            RELEASE_DATE     ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1           2012/07/13    Lung              3              8             26
# 2           2012/07/13    Lung              2              9              5
# 3           2012/07/13    Lung              1              7             18
# 4           2012/07/13    Lung              0              1              1
# 5           2012/07/13    Lung              0              4             24
# ..                  ...     ...            ...            ...            ...
# 67  2023-01-05 18:00:00      LU              0              4             14
# 68  2023-01-05 18:00:00      LU              3              3             17
# 69  2023-01-05 18:00:00      LU              3             10             15
# 70  2023-01-05 18:00:00      LU              0              0              8
# 71  2023-01-05 18:00:00      LU              1              4             15
#
#    GSR_AD_ACT_C1M GSR_AD_ACT_C1Y  ... GSR_P0_ADJ_C1M GSR_P0_ADJ_C1Y  \
# 1           91.89           77.4  ...              0              0
# 2           96.92           83.1  ...              0              0
# 3           97.37           80.7  ...              0              0
# 4             100             50  ...              0              0
# 5             100          89.89  ...              0              0
# ..            ...            ...  ...            ...            ...
# 67            100      90.573339  ...      96.060704      93.354406
# 68      94.609164      94.609164  ...              0              0
# 69      97.680288      90.037094  ...      96.060704      93.354406
# 70            100            100  ...              0              0
# 71      98.648649       93.00818  ...      96.060704      93.354406
#
#    GSR_P0_ADJ_C3Y GSR_P0_EXP_C1M GSR_P0_EXP_C1Y GSR_P0_EXP_C3Y GSR_P0_N_C1M  \
# 1               0              0              0              0           2
# 2               0              0              0              0           2
# 3               0              0              0              0            0
# 4               0              0              0              0           3
# 5               0              0              0              0            0
# ..            ...            ...            ...            ...          ...
# 67              0        0.04019       0.068767              0            1
# 68              0              0              0              0            0
# 69      56.199068        0.04019       0.068767       0.121707            1
# 70              0              0              0              0            0
# 71      56.199068        0.04019       0.068767       0.189194            1
#
#    GSR_P0_N_C1Y  YEAR MONTH
# 1            2   2012     7
# 2            2   2012     7
# 3             0  2012     7
# 4            3   2012     7
# 5             0  2012     7
# ..          ...   ...   ...
# 67            1  2022    11
# 68            0  2022    11
# 69            1  2022    11
# 70            0  2022    11
# 71            1  2022    11
#
# [1573 rows x 36 columns]

# %%
final_df.to_csv("Resources/LU_survival.csv", index=False, header=True)
