# %%
# importing dependencies

import pandas as pd
import os
import re
import calendar
import numpy as np

# %%
# grabbing all the files in the "Resources_HR" directory

excel_files = [file for file in os.listdir("Resources_PA") if not file.startswith("~") and file.lower().endswith(".xls")]

# %%
# checking to see that all files were imported

print(len(excel_files))
# Out:
# 22

# %%
concat=False;
for file in excel_files:
    year_month = re.sub("[^\d]", "", file)
    year = "20"+year_month[0:2]
    month = int(year_month[2:4])
    
    
    if(year in ["2012", "2013", "2014"]):
        sheet_name = "Table 10"
    elif(year in ['2015', '2016', '2017', '2018', '2019', '2020', '2021']):
        sheet_name = "TablesC5-C10 FiguresC1-C12"
    else:
        sheet_name = "TablesC5-C12 Figures C1-C20"
        
    
    survival_df = pd.read_excel(io='Resources_PA/'+file, sheet_name=sheet_name)

        
    if(len(survival_df.index)>0):
        survival_df = survival_df.drop(survival_df.index[0])
   
        
    survival_df_cleaned = pd.DataFrame()
    
    
    
    columns_to_keep = ["Unnamed: 0", ' ctr_cd', 'ctr_ty', 'ENTIRE_NAME', 'CTR_CD', 'CTR_TY', 'RELEASE_DATE', 'ORG', 
                   'GSR_AD_OBS_C1M', 'GSR_AD_OBS_C1Y', 'GSR_AD_OBS_C3Y', 
                   'GSR_AD_N_C1M', 'GSR_AD_N_C1Y', 'GSR_AD_N_C3Y', 
                   'GSR_P0_OBS_C1M', 'GSR_P0_OBS_C1Y', 'GSR_P0_OBS_C3Y', 
                   'GSR_P0_N_C1M', 'GSR_P0_N_C1Y', 'GSR_P0_C3Y']
    
    for column in columns_to_keep:
        if column in survival_df:
            survival_df_cleaned[column]=survival_df[column]
        elif column+" " in survival_df:
            survival_df_cleaned[column]=survival_df[column+" "]
        elif " "+column in survival_df:
            survival_df_cleaned[column]=survival_df[" "+column]
        elif " "+column+" " in survival_df:
            survival_df_cleaned[column]=survival_df[" "+column+" "]

    
    survival_df_cleaned["YEAR"]=year
    survival_df_cleaned["MONTH"]=month

    if(concat==True):
        merged_survival_df= pd.concat([merged_survival_df, survival_df_cleaned], axis=0)

    else:
        merged_survival_df=survival_df_cleaned
        
        concat=True
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 16
#      12 else:
#      13     sheet_name = "TablesC5-C12 Figures C1-C20"
# ---> 16 survival_df = pd.read_excel(io='Resources_PA/'+file, sheet_name=sheet_name)
#      19 if(len(survival_df.index)>0):
#      20     survival_df = survival_df.drop(survival_df.index[0])
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.10/site-packages/pandas/io/excel/_base.py:490, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#     489 try:
# --> 490     data = io.parse(
#     491         sheet_name=sheet_name,
#     492         header=header,
#     493         names=names,
#     494         index_col=index_col,
#     495         usecols=usecols,
#     496         squeeze=squeeze,
#     497         dtype=dtype,
#     498         converters=converters,
#     499         true_values=true_values,
#     500         false_values=false_values,
#     501         skiprows=skiprows,
#     502         nrows=nrows,
#     503         na_values=na_values,
#     504         keep_default_na=keep_default_na,
#     505         na_filter=na_filter,
#     506         verbose=verbose,
#     507         parse_dates=parse_dates,
#     508         date_parser=date_parser,
#     509         thousands=thousands,
#     510         decimal=decimal,
#     511         comment=comment,
#     512         skipfooter=skipfooter,
#     513         convert_float=convert_float,
#     514         mangle_dupe_cols=mangle_dupe_cols,
#     515     )
#     516 finally:
#     517     # make sure to close opened file handles
#     518     if should_close:
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.10/site-packages/pandas/io/excel/_base.py:1734, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, squeeze, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#    1700 def parse(
#    1701     self,
#    1702     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)
#    1721     **kwds,
#    1722 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1723     """
#    1724     Parse specified sheet(s) into a DataFrame.
#    1725
#    (...)
#    1732         DataFrame from the passed in Excel file.
#    1733     """
# -> 1734     return self._reader.parse(
#    1735         sheet_name=sheet_name,
#    1736         header=header,
#    1737         names=names,
#    1738         index_col=index_col,
#    1739         usecols=usecols,
#    1740         squeeze=squeeze,
#    1741         converters=converters,
#    1742         true_values=true_values,
#    1743         false_values=false_values,
#    1744         skiprows=skiprows,
#    1745         nrows=nrows,
#    1746         na_values=na_values,
#    1747         parse_dates=parse_dates,
#    1748         date_parser=date_parser,
#    1749         thousands=thousands,
#    1750         comment=comment,
#    1751         skipfooter=skipfooter,
#    1752         convert_float=convert_float,
#    1753         mangle_dupe_cols=mangle_dupe_cols,
#    1754         **kwds,
#    1755     )
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.10/site-packages/pandas/io/excel/_base.py:760, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, squeeze, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     757     print(f"Reading sheet {asheetname}")
#     759 if isinstance(asheetname, str):
# --> 760     sheet = self.get_sheet_by_name(asheetname)
#     761 else:  # assume an integer if not a string
#     762     sheet = self.get_sheet_by_index(asheetname)
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.10/site-packages/pandas/io/excel/_xlrd.py:57, in XlrdReader.get_sheet_by_name(self, name)
#      56 def get_sheet_by_name(self, name):
# ---> 57     self.raise_if_bad_sheet_by_name(name)
#      58     return self.book.sheet_by_name(name)
#
# File ~/opt/anaconda3/envs/PythonData/lib/python3.10/site-packages/pandas/io/excel/_base.py:602, in BaseExcelReader.raise_if_bad_sheet_by_name(self, name)
#     600 def raise_if_bad_sheet_by_name(self, name: str) -> None:
#     601     if name not in self.sheet_names:
# --> 602         raise ValueError(f"Worksheet named '{name}' not found")
#
# ValueError: Worksheet named 'Table 10' not found

# %%
merged_survival_df
# Out:
#                                             Unnamed: 0  ctr_cd ctr_ty  \
# 1    University of South Alabama Medical Center (AL...   ALAM    TX1
# 2               University of Alabama Hospital (ALUA)    ALUA    TX1
# 3                       Baptist Medical Center (ARBH)    ARBH    TX1
# 4                 Arkansas Children's Hospital (ARCH)    ARCH    TX1
# 5                          UAMS Medical Center (ARUA)    ARUA    TX1
# ..                                                 ...     ...    ...
# 243           Children's Hospital of Wisconsin (WICH)    WICH    TX1
# 244       Froedtert Memorial Lutheran Hospital (WISE)    WISE    TX1
# 245           Aurora St. Luke's Medical Center (WISL)    WISL    TX1
# 246  University of Wisconsin Hospital and Clinics (...   WIUW    TX1
# 247             Charleston Area Medical Center (WVCA)    WVCA    TX1
#
#      RELEASE_DATE       ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1     2012/07/13    Kidney                                            6
# 2     2012/07/13    Kidney              8             29             71
# 3     2012/07/13    Kidney              3              8             18
# 4     2012/07/13    Kidney              0              0
# 5     2012/07/13    Kidney              3              6             30
# ..            ...       ...            ...            ...            ...
# 243   2014/06/17    Kidney              0              0              1
# 244   2014/06/17    Kidney              1              4             26
# 245   2014/06/17    Kidney              1              7             10
# 246   2014/06/17    Kidney              7             33             80
# 247   2014/06/17    Kidney              2              5             11
#
#     GSR_AD_N_C1M GSR_AD_N_C1Y  ... GSR_P0_OBS_C1M GSR_P0_OBS_C1Y  \
# 1                              ...
# 2           573          573   ...             0              3
# 3            86           86   ...
# 4             2            2   ...             0              1
# 5           140          140   ...
# ..           ...          ...  ...            ...            ...
# 243           6            6   ...             0              0
# 244         195          195   ...
# 245          73           73   ...
# 246         606          606   ...             0              0
# 247          98           98   ...             1              1
#
#     GSR_P0_OBS_C3Y GSR_P0_N_C1M GSR_P0_N_C1Y  YEAR MONTH  ENTIRE_NAME CTR_CD  \
# 1                                             2012     7          NaN    NaN
# 2               6           53           53   2012     7          NaN    NaN
# 3                                             2012     7          NaN    NaN
# 4               2           19           19   2012     7          NaN    NaN
# 5                                             2012     7          NaN    NaN
# ..             ...          ...          ...   ...   ...          ...    ...
# 243             1           18           18   2014     6          NaN    NaN
# 244                                           2014     6          NaN    NaN
# 245                                           2014     6          NaN    NaN
# 246             0            6            6   2014     6          NaN    NaN
# 247             1            4            4   2014     6          NaN    NaN
#
#     CTR_TY
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# ..     ...
# 243    NaN
# 244    NaN
# 245    NaN
# 246    NaN
# 247    NaN
#
# [5347 rows x 21 columns]

# %%
column_adding = merged_survival_df.copy()

# df['b'] = df['b'].fillna(df['a'])

column_adding['ENTIRE_NAME'] = column_adding['ENTIRE_NAME'].fillna(column_adding['Unnamed: 0'])

# column_adding['ENTIRE_NAME'] = column_adding['ENTIRE_NAME'] + column_adding['Unnamed: 0']

column_adding
# Out:
#                                             Unnamed: 0  ctr_cd ctr_ty  \
# 1    University of South Alabama Medical Center (AL...   ALAM    TX1
# 2               University of Alabama Hospital (ALUA)    ALUA    TX1
# 3                       Baptist Medical Center (ARBH)    ARBH    TX1
# 4                 Arkansas Children's Hospital (ARCH)    ARCH    TX1
# 5                          UAMS Medical Center (ARUA)    ARUA    TX1
# ..                                                 ...     ...    ...
# 243           Children's Hospital of Wisconsin (WICH)    WICH    TX1
# 244       Froedtert Memorial Lutheran Hospital (WISE)    WISE    TX1
# 245           Aurora St. Luke's Medical Center (WISL)    WISL    TX1
# 246  University of Wisconsin Hospital and Clinics (...   WIUW    TX1
# 247             Charleston Area Medical Center (WVCA)    WVCA    TX1
#
#      RELEASE_DATE       ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1     2012/07/13    Kidney                                            6
# 2     2012/07/13    Kidney              8             29             71
# 3     2012/07/13    Kidney              3              8             18
# 4     2012/07/13    Kidney              0              0
# 5     2012/07/13    Kidney              3              6             30
# ..            ...       ...            ...            ...            ...
# 243   2014/06/17    Kidney              0              0              1
# 244   2014/06/17    Kidney              1              4             26
# 245   2014/06/17    Kidney              1              7             10
# 246   2014/06/17    Kidney              7             33             80
# 247   2014/06/17    Kidney              2              5             11
#
#     GSR_AD_N_C1M GSR_AD_N_C1Y  ... GSR_P0_OBS_C1M GSR_P0_OBS_C1Y  \
# 1                              ...
# 2           573          573   ...             0              3
# 3            86           86   ...
# 4             2            2   ...             0              1
# 5           140          140   ...
# ..           ...          ...  ...            ...            ...
# 243           6            6   ...             0              0
# 244         195          195   ...
# 245          73           73   ...
# 246         606          606   ...             0              0
# 247          98           98   ...             1              1
#
#     GSR_P0_OBS_C3Y GSR_P0_N_C1M GSR_P0_N_C1Y  YEAR MONTH  \
# 1                                             2012     7
# 2               6           53           53   2012     7
# 3                                             2012     7
# 4               2           19           19   2012     7
# 5                                             2012     7
# ..             ...          ...          ...   ...   ...
# 243             1           18           18   2014     6
# 244                                           2014     6
# 245                                           2014     6
# 246             0            6            6   2014     6
# 247             1            4            4   2014     6
#
#                                            ENTIRE_NAME CTR_CD CTR_TY
# 1    University of South Alabama Medical Center (AL...    NaN    NaN
# 2               University of Alabama Hospital (ALUA)     NaN    NaN
# 3                       Baptist Medical Center (ARBH)     NaN    NaN
# 4                 Arkansas Children's Hospital (ARCH)     NaN    NaN
# 5                          UAMS Medical Center (ARUA)     NaN    NaN
# ..                                                 ...    ...    ...
# 243           Children's Hospital of Wisconsin (WICH)     NaN    NaN
# 244       Froedtert Memorial Lutheran Hospital (WISE)     NaN    NaN
# 245           Aurora St. Luke's Medical Center (WISL)     NaN    NaN
# 246  University of Wisconsin Hospital and Clinics (...    NaN    NaN
# 247             Charleston Area Medical Center (WVCA)     NaN    NaN
#
# [5347 rows x 21 columns]

# %%
column_adding['YEAR'].unique()
# Out:
# array(['2012', '2013', '2018', '2019', '2015', '2021', '2014', '2020',
#        '2017', '2022', '2016'], dtype=object)

# %%
# df.loc[df['column_name'].isin(some_values)]

column_adding.loc[column_adding['YEAR']=='2012']
# Out:
#                                             Unnamed: 0  ctr_cd ctr_ty  \
# 1    University of South Alabama Medical Center (AL...   ALAM    TX1
# 2               University of Alabama Hospital (ALUA)    ALUA    TX1
# 3                       Baptist Medical Center (ARBH)    ARBH    TX1
# 4                 Arkansas Children's Hospital (ARCH)    ARCH    TX1
# 5                          UAMS Medical Center (ARUA)    ARUA    TX1
# ..                                                 ...     ...    ...
# 249       Froedtert Memorial Lutheran Hospital (WISE)    WISE    TX1
# 250           Aurora St. Luke's Medical Center (WISL)    WISL    TX1
# 251  University of Wisconsin Hospital and Clinics (...   WIUW    TX1
# 252             Charleston Area Medical Center (WVCA)    WVCA    TX1
# 253          West Virginia University Hospital (WVWU)    WVWU    TX1
#
#      RELEASE_DATE       ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1     2012/07/13    Kidney                                            6
# 2     2012/07/13    Kidney              8             29             71
# 3     2012/07/13    Kidney              3              8             18
# 4     2012/07/13    Kidney              0              0
# 5     2012/07/13    Kidney              3              6             30
# ..            ...       ...            ...            ...            ...
# 249   2012/07/13    Kidney              8             11             24
# 250   2012/07/13    Kidney              3              5             11
# 251   2012/07/13    Kidney              8             25            113
# 252   2012/07/13    Kidney              2              5             15
# 253   2012/07/13    Kidney                                            1
#
#     GSR_AD_N_C1M GSR_AD_N_C1Y  ... GSR_P0_OBS_C1M GSR_P0_OBS_C1Y  \
# 1                              ...
# 2           573          573   ...             0              3
# 3            86           86   ...
# 4             2            2   ...             0              1
# 5           140          140   ...
# ..           ...          ...  ...            ...            ...
# 249         219          219   ...
# 250          71           71   ...
# 251         590          590   ...             0              0
# 252          87           87   ...             1              1
# 253                            ...
#
#     GSR_P0_OBS_C3Y GSR_P0_N_C1M GSR_P0_N_C1Y  YEAR MONTH  \
# 1                                             2012     7
# 2               6           53           53   2012     7
# 3                                             2012     7
# 4               2           19           19   2012     7
# 5                                             2012     7
# ..             ...          ...          ...   ...   ...
# 249                                           2012     7
# 250                                           2012     7
# 251             0           15           15   2012     7
# 252             0            5            5   2012     7
# 253                                           2012     7
#
#                                            ENTIRE_NAME CTR_CD CTR_TY
# 1    University of South Alabama Medical Center (AL...    NaN    NaN
# 2               University of Alabama Hospital (ALUA)     NaN    NaN
# 3                       Baptist Medical Center (ARBH)     NaN    NaN
# 4                 Arkansas Children's Hospital (ARCH)     NaN    NaN
# 5                          UAMS Medical Center (ARUA)     NaN    NaN
# ..                                                 ...    ...    ...
# 249       Froedtert Memorial Lutheran Hospital (WISE)     NaN    NaN
# 250           Aurora St. Luke's Medical Center (WISL)     NaN    NaN
# 251  University of Wisconsin Hospital and Clinics (...    NaN    NaN
# 252             Charleston Area Medical Center (WVCA)     NaN    NaN
# 253          West Virginia University Hospital (WVWU)     NaN    NaN
#
# [253 rows x 21 columns]

# %%
column_adding.columns
# Out:
# Index(['Unnamed: 0', ' ctr_cd', 'ctr_ty', 'RELEASE_DATE', 'ORG',
#        'GSR_AD_OBS_C1M', 'GSR_AD_OBS_C1Y', 'GSR_AD_OBS_C3Y', 'GSR_AD_N_C1M',
#        'GSR_AD_N_C1Y', 'GSR_AD_N_C3Y', 'GSR_P0_OBS_C1M', 'GSR_P0_OBS_C1Y',
#        'GSR_P0_OBS_C3Y', 'GSR_P0_N_C1M', 'GSR_P0_N_C1Y', 'YEAR', 'MONTH',
#        'ENTIRE_NAME', 'CTR_CD', 'CTR_TY'],
#       dtype='object')

# %%
# column_adding['ENTIRE_NAME'] = column_adding['ENTIRE_NAME'].fillna(column_adding['Unnamed: 0'])
column_adding['CTR_CD'] = column_adding['CTR_CD'].fillna(column_adding[' ctr_cd'])
column_adding['CTR_TY'] = column_adding['CTR_TY'].fillna(column_adding['ctr_ty'])

column_adding
# Out:
#                                             Unnamed: 0  ctr_cd ctr_ty  \
# 1    University of South Alabama Medical Center (AL...   ALAM    TX1
# 2               University of Alabama Hospital (ALUA)    ALUA    TX1
# 3                       Baptist Medical Center (ARBH)    ARBH    TX1
# 4                 Arkansas Children's Hospital (ARCH)    ARCH    TX1
# 5                          UAMS Medical Center (ARUA)    ARUA    TX1
# ..                                                 ...     ...    ...
# 243           Children's Hospital of Wisconsin (WICH)    WICH    TX1
# 244       Froedtert Memorial Lutheran Hospital (WISE)    WISE    TX1
# 245           Aurora St. Luke's Medical Center (WISL)    WISL    TX1
# 246  University of Wisconsin Hospital and Clinics (...   WIUW    TX1
# 247             Charleston Area Medical Center (WVCA)    WVCA    TX1
#
#      RELEASE_DATE       ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1     2012/07/13    Kidney                                            6
# 2     2012/07/13    Kidney              8             29             71
# 3     2012/07/13    Kidney              3              8             18
# 4     2012/07/13    Kidney              0              0
# 5     2012/07/13    Kidney              3              6             30
# ..            ...       ...            ...            ...            ...
# 243   2014/06/17    Kidney              0              0              1
# 244   2014/06/17    Kidney              1              4             26
# 245   2014/06/17    Kidney              1              7             10
# 246   2014/06/17    Kidney              7             33             80
# 247   2014/06/17    Kidney              2              5             11
#
#     GSR_AD_N_C1M GSR_AD_N_C1Y  ... GSR_P0_OBS_C1M GSR_P0_OBS_C1Y  \
# 1                              ...
# 2           573          573   ...             0              3
# 3            86           86   ...
# 4             2            2   ...             0              1
# 5           140          140   ...
# ..           ...          ...  ...            ...            ...
# 243           6            6   ...             0              0
# 244         195          195   ...
# 245          73           73   ...
# 246         606          606   ...             0              0
# 247          98           98   ...             1              1
#
#     GSR_P0_OBS_C3Y GSR_P0_N_C1M GSR_P0_N_C1Y  YEAR MONTH  \
# 1                                             2012     7
# 2               6           53           53   2012     7
# 3                                             2012     7
# 4               2           19           19   2012     7
# 5                                             2012     7
# ..             ...          ...          ...   ...   ...
# 243             1           18           18   2014     6
# 244                                           2014     6
# 245                                           2014     6
# 246             0            6            6   2014     6
# 247             1            4            4   2014     6
#
#                                            ENTIRE_NAME  CTR_CD CTR_TY
# 1    University of South Alabama Medical Center (AL...   ALAM    TX1
# 2               University of Alabama Hospital (ALUA)    ALUA    TX1
# 3                       Baptist Medical Center (ARBH)    ARBH    TX1
# 4                 Arkansas Children's Hospital (ARCH)    ARCH    TX1
# 5                          UAMS Medical Center (ARUA)    ARUA    TX1
# ..                                                 ...     ...    ...
# 243           Children's Hospital of Wisconsin (WICH)    WICH    TX1
# 244       Froedtert Memorial Lutheran Hospital (WISE)    WISE    TX1
# 245           Aurora St. Luke's Medical Center (WISL)    WISL    TX1
# 246  University of Wisconsin Hospital and Clinics (...   WIUW    TX1
# 247             Charleston Area Medical Center (WVCA)    WVCA    TX1
#
# [5347 rows x 21 columns]

# %%
column_adding.loc[column_adding['YEAR']=='2021']
# Out:
#     Unnamed: 0  ctr_cd ctr_ty         RELEASE_DATE ORG GSR_AD_OBS_C1M  \
# 1          NaN     NaN    NaN  2021-07-06 19:00:00  KI            NaN
# 2          NaN     NaN    NaN  2021-07-06 19:00:00  KI              2
# 3          NaN     NaN    NaN  2021-07-06 19:00:00  KI              0
# 4          NaN     NaN    NaN  2021-07-06 19:00:00  KI            NaN
# 5          NaN     NaN    NaN  2021-07-06 19:00:00  KI              0
# ..         ...     ...    ...                  ...  ..            ...
# 233        NaN     NaN    NaN  2022-01-06 18:00:00  KI              1
# 234        NaN     NaN    NaN  2022-01-06 18:00:00  KI              0
# 235        NaN     NaN    NaN  2022-01-06 18:00:00  KI              7
# 236        NaN     NaN    NaN  2022-01-06 18:00:00  KI              4
# 237        NaN     NaN    NaN  2022-01-06 18:00:00  KI              0
#
#     GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y GSR_AD_N_C1M GSR_AD_N_C1Y  ...  \
# 1              NaN            NaN          NaN          NaN  ...
# 2               14             37          572          572  ...
# 3                0              0           15           15  ...
# 4              NaN            NaN          NaN          NaN  ...
# 5                7             15          301          301  ...
# ..             ...            ...          ...          ...  ...
# 233              5             15          138          138  ...
# 234              0              3           91           91  ...
# 235             25             46          670          670  ...
# 236             11              7          205          205  ...
# 237              0            NaN            6            6  ...
#
#     GSR_P0_OBS_C1M GSR_P0_OBS_C1Y GSR_P0_OBS_C3Y GSR_P0_N_C1M GSR_P0_N_C1Y  \
# 1                0              0              0           24           24
# 2                0              0            NaN            1            1
# 3              NaN            NaN            NaN          NaN          NaN
# 4                0              0              0           19           19
# 5              NaN            NaN            NaN          NaN          NaN
# ..             ...            ...            ...          ...          ...
# 233            NaN            NaN            NaN          NaN          NaN
# 234            NaN            NaN            NaN          NaN          NaN
# 235              0              0              0           11           11
# 236            NaN            NaN              0          NaN          NaN
# 237            NaN            NaN            NaN          NaN          NaN
#
#      YEAR MONTH                                        ENTIRE_NAME CTR_CD  \
# 1    2021     5                       Children's of Alabama (ALCH)   ALCH
# 2    2021     5              University of Alabama Hospital (ALUA)   ALUA
# 3    2021     5                Birmingham VA Medical Center (ALVA)   ALVA
# 4    2021     5                Arkansas Children's Hospital (ARCH)   ARCH
# 5    2021     5                         UAMS Medical Center (ARUA)   ARUA
# ..    ...   ...                                                ...    ...
# 233  2021    11        Froedtert Memorial Lutheran Hospital (WISE)   WISE
# 234  2021    11            Aurora St. Luke's Medical Center (WISL)   WISL
# 235  2021    11  University of Wisconsin Hospital and Clinics (...   WIUW
# 236  2021    11              Charleston Area Medical Center (WVCA)   WVCA
# 237  2021    11           West Virginia University Hospital (WVWU)   WVWU
#
#     CTR_TY
# 1      TX1
# 2      TX1
# 3      TX1
# 4      TX1
# 5      TX1
# ..     ...
# 233    TX1
# 234    TX1
# 235    TX1
# 236    TX1
# 237    TX1
#
# [472 rows x 21 columns]

# %%
survival_final = column_adding.drop(columns=['Unnamed: 0', ' ctr_cd', 'ctr_ty'])

survival_final
# Out:
#      RELEASE_DATE       ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1     2012/07/13    Kidney                                            6
# 2     2012/07/13    Kidney              8             29             71
# 3     2012/07/13    Kidney              3              8             18
# 4     2012/07/13    Kidney              0              0
# 5     2012/07/13    Kidney              3              6             30
# ..            ...       ...            ...            ...            ...
# 243   2014/06/17    Kidney              0              0              1
# 244   2014/06/17    Kidney              1              4             26
# 245   2014/06/17    Kidney              1              7             10
# 246   2014/06/17    Kidney              7             33             80
# 247   2014/06/17    Kidney              2              5             11
#
#     GSR_AD_N_C1M GSR_AD_N_C1Y GSR_AD_N_C3Y GSR_P0_OBS_C1M GSR_P0_OBS_C1Y  \
# 1                                      21
# 2           573          573          659              0              3
# 3            86           86           93
# 4             2            2                           0              1
# 5           140          140          155
# ..           ...          ...          ...            ...            ...
# 243           6            6            2              0              0
# 244         195          195          241
# 245          73           73           69
# 246         606          606          594              0              0
# 247          98           98           85              1              1
#
#     GSR_P0_OBS_C3Y GSR_P0_N_C1M GSR_P0_N_C1Y  YEAR  MONTH  \
# 1                                             2012      7
# 2               6           53           53   2012      7
# 3                                             2012      7
# 4               2           19           19   2012      7
# 5                                             2012      7
# ..             ...          ...          ...   ...    ...
# 243             1           18           18   2014      6
# 244                                           2014      6
# 245                                           2014      6
# 246             0            6            6   2014      6
# 247             1            4            4   2014      6
#
#                                            ENTIRE_NAME  CTR_CD CTR_TY
# 1    University of South Alabama Medical Center (AL...   ALAM    TX1
# 2               University of Alabama Hospital (ALUA)    ALUA    TX1
# 3                       Baptist Medical Center (ARBH)    ARBH    TX1
# 4                 Arkansas Children's Hospital (ARCH)    ARCH    TX1
# 5                          UAMS Medical Center (ARUA)    ARUA    TX1
# ..                                                 ...     ...    ...
# 243           Children's Hospital of Wisconsin (WICH)    WICH    TX1
# 244       Froedtert Memorial Lutheran Hospital (WISE)    WISE    TX1
# 245           Aurora St. Luke's Medical Center (WISL)    WISL    TX1
# 246  University of Wisconsin Hospital and Clinics (...   WIUW    TX1
# 247             Charleston Area Medical Center (WVCA)    WVCA    TX1
#
# [5347 rows x 18 columns]

# %%
first_column = survival_final.pop('ENTIRE_NAME')
second_column = survival_final.pop('CTR_CD')
third_column = survival_final.pop('CTR_TY')

survival_final.insert(0, 'ENTIRE_NAME', first_column)
survival_final.insert(1, 'CTR_CD', second_column)
survival_final.insert(2, 'CTR_TY', third_column)

survival_final
# Out:
#                                            ENTIRE_NAME  CTR_CD CTR_TY  \
# 1    University of South Alabama Medical Center (AL...   ALAM    TX1
# 2               University of Alabama Hospital (ALUA)    ALUA    TX1
# 3                       Baptist Medical Center (ARBH)    ARBH    TX1
# 4                 Arkansas Children's Hospital (ARCH)    ARCH    TX1
# 5                          UAMS Medical Center (ARUA)    ARUA    TX1
# ..                                                 ...     ...    ...
# 243           Children's Hospital of Wisconsin (WICH)    WICH    TX1
# 244       Froedtert Memorial Lutheran Hospital (WISE)    WISE    TX1
# 245           Aurora St. Luke's Medical Center (WISL)    WISL    TX1
# 246  University of Wisconsin Hospital and Clinics (...   WIUW    TX1
# 247             Charleston Area Medical Center (WVCA)    WVCA    TX1
#
#      RELEASE_DATE       ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1     2012/07/13    Kidney                                            6
# 2     2012/07/13    Kidney              8             29             71
# 3     2012/07/13    Kidney              3              8             18
# 4     2012/07/13    Kidney              0              0
# 5     2012/07/13    Kidney              3              6             30
# ..            ...       ...            ...            ...            ...
# 243   2014/06/17    Kidney              0              0              1
# 244   2014/06/17    Kidney              1              4             26
# 245   2014/06/17    Kidney              1              7             10
# 246   2014/06/17    Kidney              7             33             80
# 247   2014/06/17    Kidney              2              5             11
#
#     GSR_AD_N_C1M GSR_AD_N_C1Y GSR_AD_N_C3Y GSR_P0_OBS_C1M GSR_P0_OBS_C1Y  \
# 1                                      21
# 2           573          573          659              0              3
# 3            86           86           93
# 4             2            2                           0              1
# 5           140          140          155
# ..           ...          ...          ...            ...            ...
# 243           6            6            2              0              0
# 244         195          195          241
# 245          73           73           69
# 246         606          606          594              0              0
# 247          98           98           85              1              1
#
#     GSR_P0_OBS_C3Y GSR_P0_N_C1M GSR_P0_N_C1Y  YEAR  MONTH
# 1                                             2012      7
# 2               6           53           53   2012      7
# 3                                             2012      7
# 4               2           19           19   2012      7
# 5                                             2012      7
# ..             ...          ...          ...   ...    ...
# 243             1           18           18   2014      6
# 244                                           2014      6
# 245                                           2014      6
# 246             0            6            6   2014      6
# 247             1            4            4   2014      6
#
# [5347 rows x 18 columns]

# %%
final_df = survival_final.copy()
final_df
# Out:
#                                            ENTIRE_NAME  CTR_CD CTR_TY  \
# 1    University of South Alabama Medical Center (AL...   ALAM    TX1
# 2               University of Alabama Hospital (ALUA)    ALUA    TX1
# 3                       Baptist Medical Center (ARBH)    ARBH    TX1
# 4                 Arkansas Children's Hospital (ARCH)    ARCH    TX1
# 5                          UAMS Medical Center (ARUA)    ARUA    TX1
# ..                                                 ...     ...    ...
# 243           Children's Hospital of Wisconsin (WICH)    WICH    TX1
# 244       Froedtert Memorial Lutheran Hospital (WISE)    WISE    TX1
# 245           Aurora St. Luke's Medical Center (WISL)    WISL    TX1
# 246  University of Wisconsin Hospital and Clinics (...   WIUW    TX1
# 247             Charleston Area Medical Center (WVCA)    WVCA    TX1
#
#      RELEASE_DATE       ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1     2012/07/13    Kidney                                            6
# 2     2012/07/13    Kidney              8             29             71
# 3     2012/07/13    Kidney              3              8             18
# 4     2012/07/13    Kidney              0              0
# 5     2012/07/13    Kidney              3              6             30
# ..            ...       ...            ...            ...            ...
# 243   2014/06/17    Kidney              0              0              1
# 244   2014/06/17    Kidney              1              4             26
# 245   2014/06/17    Kidney              1              7             10
# 246   2014/06/17    Kidney              7             33             80
# 247   2014/06/17    Kidney              2              5             11
#
#     GSR_AD_N_C1M GSR_AD_N_C1Y GSR_AD_N_C3Y GSR_P0_OBS_C1M GSR_P0_OBS_C1Y  \
# 1                                      21
# 2           573          573          659              0              3
# 3            86           86           93
# 4             2            2                           0              1
# 5           140          140          155
# ..           ...          ...          ...            ...            ...
# 243           6            6            2              0              0
# 244         195          195          241
# 245          73           73           69
# 246         606          606          594              0              0
# 247          98           98           85              1              1
#
#     GSR_P0_OBS_C3Y GSR_P0_N_C1M GSR_P0_N_C1Y  YEAR  MONTH
# 1                                             2012      7
# 2               6           53           53   2012      7
# 3                                             2012      7
# 4               2           19           19   2012      7
# 5                                             2012      7
# ..             ...          ...          ...   ...    ...
# 243             1           18           18   2014      6
# 244                                           2014      6
# 245                                           2014      6
# 246             0            6            6   2014      6
# 247             1            4            4   2014      6
#
# [5347 rows x 18 columns]

# %%
final_df.to_csv("Resources/KI_survival.csv", index=False, header=True)
