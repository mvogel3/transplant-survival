# %%
import pandas as pd

# %%
#get the first sheet name to turn into a dataframe - this will be for transplants from deceased donors. 
sheet_name = 'Figures C1-C2 - Living'

c12_excel_files = ['1506_KI.XLS', '1512_KI.XLS', '1606_KI.XLS', '1701_KI.xls', '1707_KI.xls', '1711_KI.xls',
                  '1808_KI.xls', '1811_KI.xls', '1905_KI.xls', '1911_KI.xls', '2006_KI.xls', '2011_KI.xls',
                  '2105_KI.xls', '2111_KI.xls', '2205_KI.xls', '2211_KI.xls']

# %%
#import all the excel sheets from Figures C1-C2 - Living as dataframes. 


df_1506_c1c27l = pd.read_excel('kidney/1506_KI.XLS', sheet_name=sheet_name)
df_1512_c1c27l = pd.read_excel('kidney/1512_KI.XLS', sheet_name=sheet_name)
df_1606_c1c27l = pd.read_excel('kidney/1606_KI.XLS', sheet_name=sheet_name)
df_1701_c1c27l = pd.read_excel('kidney/1701_KI.xls', sheet_name=sheet_name)
df_1707_c1c27l = pd.read_excel('kidney/1707_KI.xls', sheet_name=sheet_name)
df_1711_c1c27l = pd.read_excel('kidney/1711_KI.xls', sheet_name=sheet_name)
df_1808_c1c27l = pd.read_excel('kidney/1808_KI.xls', sheet_name=sheet_name)
df_1811_c1c27l = pd.read_excel('kidney/1811_KI.xls', sheet_name=sheet_name)
df_1905_c1c27l = pd.read_excel('kidney/1905_KI.xls', sheet_name=sheet_name)
df_1911_c1c27l = pd.read_excel('kidney/1911_KI.xls', sheet_name=sheet_name)
df_2006_c1c27l = pd.read_excel('kidney/2006_KI.xls', sheet_name=sheet_name)
df_2011_c1c27l = pd.read_excel('kidney/2011_KI.xls', sheet_name=sheet_name)
df_2105_c1c27l = pd.read_excel('kidney/2105_KI.xls', sheet_name=sheet_name)
df_2111_c1c27l = pd.read_excel('kidney/2111_KI.xls', sheet_name=sheet_name)
df_2205_c1c27l = pd.read_excel('kidney/2205_KI.xls', sheet_name=sheet_name)
df_2211_c1c27l = pd.read_excel('kidney/2211_KI.xls', sheet_name=sheet_name)

# %%
#get Table 7 excel files
sheet_name = 'Table 7 - Living'

tb7_excel_files = ['1207_KI.XLS', '1301_KI.XLS', '1307_KI.XLS', '1401_KI.XLS', '1406_KI.XLS', '1412_KI.XLS']

df_1207_c1c27l = pd.read_excel('kidney/1207_KI.XLS', sheet_name=sheet_name)
df_1301_c1c27l = pd.read_excel('kidney/1301_KI.XLS', sheet_name=sheet_name)
df_1307_c1c27l = pd.read_excel('kidney/1307_KI.XLS', sheet_name=sheet_name)
df_1401_c1c27l = pd.read_excel('kidney/1401_KI.XLS', sheet_name=sheet_name)
df_1406_c1c27l = pd.read_excel('kidney/1406_KI.XLS', sheet_name=sheet_name)
df_1412_c1c27l = pd.read_excel('kidney/1412_KI.XLS', sheet_name=sheet_name)

# %%
# %whos
# Out:
# Variable          Type         Data/Info
# ----------------------------------------
# c12_excel_files   list         n=16
# df_1207_c1c27l    DataFrame                             <...>n[228 rows x 176 columns]
# df_1301_c1c27l    DataFrame                             <...>n[227 rows x 176 columns]
# df_1307_c1c27l    DataFrame                             <...>n[228 rows x 176 columns]
# df_1401_c1c27l    DataFrame                             <...>n[225 rows x 176 columns]
# df_1406_c1c27l    DataFrame                             <...>n[225 rows x 176 columns]
# df_1412_c1c27l    DataFrame                             <...>n[222 rows x 176 columns]
# df_1506_c1c27l    DataFrame                             <...>n[224 rows x 176 columns]
# df_1512_c1c27l    DataFrame                             <...>n[221 rows x 176 columns]
# df_1606_c1c27l    DataFrame                             <...>n[225 rows x 176 columns]
# ...

# %%
# df_1207_c1c27l
# df_1301_c1c27l
# df_1307_c1c27l
# df_1401_c1c27l
# df_1406_c1c27l
# df_1412_c1c27l
# df_1506_c1c27l
# df_1512_c1c27l
# df_1606_c1c27l
# df_1701_c1c27l
# df_1707_c1c27l
# df_1711_c1c27l
# df_1808_c1c27l
# df_1811_c1c27l
# df_1905_c1c27l
# df_1911_c1c27l
# df_2006_c1c27l
# df_2011_c1c27l
# df_2105_c1c27l
# df_2111_c1c27l
# df_2205_c1c27l
# df_2211_c1c27l

# %%
#create a list of dataframes from sheet Figures C1-C2 - Living or Table 7 - Living which is: C1C27L
c1c27l_df_list = [df_1506_c1c27l, df_1512_c1c27l, df_1606_c1c27l, df_1701_c1c27l, df_1707_c1c27l, 
                  df_1711_c1c27l, df_1808_c1c27l, df_1811_c1c27l, df_1905_c1c27l, df_1911_c1c27l,
                  df_2006_c1c27l, df_2011_c1c27l, df_2105_c1c27l, df_2111_c1c27l, df_2205_c1c27l,
                  df_2211_c1c27l, df_1207_c1c27l, df_1301_c1c27l, df_1307_c1c27l, df_1401_c1c27l,
                  df_1406_c1c27l, df_1412_c1c27l]

# %%
#remove leading whitespace from columns from dataframes
df_1207_c1c27l.columns = df_1207_c1c27l.columns.str.strip()
df_1301_c1c27l.columns = df_1301_c1c27l.columns.str.strip()
df_1307_c1c27l.columns = df_1307_c1c27l.columns.str.strip()
df_1401_c1c27l.columns = df_1401_c1c27l.columns.str.strip()
df_1406_c1c27l.columns = df_1406_c1c27l.columns.str.strip()
df_1412_c1c27l.columns = df_1412_c1c27l.columns.str.strip()
df_1506_c1c27l.columns = df_1506_c1c27l.columns.str.strip()
df_1512_c1c27l.columns = df_1512_c1c27l.columns.str.strip()
df_1606_c1c27l.columns = df_1606_c1c27l.columns.str.strip()

# %%
#this list of columns to keep
col_keep_l = ['ENTIRE_NAME', 'CTR_CD', 'CTR_TY', 'RELEASE_DATE', 'ORG', 'RCL_A10_C', 'RCL_A17_C', 
              'RCL_A2_C', 'RCL_A34_C', 'RCL_A49_C', 'RCL_A64_C', 'RCL_A65P_C', 'RCL_AU_C', 'RCL_BAB_C', 
              'RCL_BA_C', 'RCL_BB_C','RCL_BO_C', 'RCL_BMI20_C', 'RCL_BMI25_C', 'RCL_BMI30_C', 'RCL_BMI31P_C', 
              'RCL_BMINR_C', 'RCL_BU_C', 'RCL_GF_C', 'RCL_GM_C', 'RCL_GU_C', 'RCL_ICU_C', 'RCL_HOSPNR_C', 
              'RCL_HOSP_C', 'RCL_PTXN_C', 'RCL_PTXU_C', 'RCL_PTXY_C','RCL_NOTHOSP_C', 'RCL_N_C', 'YEAR', 'MONTH', 
              'D_OR_L']

# %%
print(len(col_keep_l))
# Out:
# 37

# %%
#remove white space from column names
col_keep_strip_l = [s.lstrip() for s in col_keep_l]

# %%
#create a dataframes list that need the aggregation for combing age group data
agg_df_list_l = [df_1911_c1c27l, df_2006_c1c27l, df_2011_c1c27l, df_2105_c1c27l, df_2111_c1c27l, 
          df_2205_c1c27l, df_2211_c1c27l]

column_a69_l = 'RCL_A69_C'
column_a70_l = 'RCL_A70P_C'
column_a65_l = 'RCL_A65P_C'

for df in agg_df_list_l:
    #add them together
    df[column_a65_l] = df[column_a69_l] + df[column_a70_l]
    print(df[column_a65_l][0])
# Out:
# 14.705882353
# 12.5
# 20.6896551721
# 24.999999999899998
# 15.909090909100001
# 20.0
# 31.3725490192

# %%
#create a dataframes list that need the aggregation for combing age group data
agg_df_list_bmi = [df_1911_c1c27l, df_2006_c1c27l, df_2011_c1c27l, df_2105_c1c27l, df_2111_c1c27l, 
          df_2205_c1c27l, df_2211_c1c27l]

#take columns RCC_BMI35_C + RCC_BMI40_C + RCC_BMI41P_C = RCC_BMI31P_C
#This is for BMI greater than 35, 40 and 41 and combining them to be greater than 31 BMI

column_bmi35_l = 'RCL_BMI35_C'
column_bmi40_l = 'RCL_BMI40_C'
column_bmi41_l = 'RCL_BMI41P_C'
column_bmi31_l = 'RCL_BMI31P_C'

for df in agg_df_list_bmi:

    #add them together
    df[column_bmi31_l] = df[column_bmi35_l] + df[column_bmi40_l] + df[column_bmi41_l]
    print(df[column_bmi31_l][0])
# Out:
# 20.5882352938
# 40.0
# 37.931034482
# 24.9999999998
# 29.5454545462
# 32.0
# 35.2941176474

# %%
#add Unknown Age column and set it to zero
agg_df_list_au = [df_1911_c1c27l, df_2006_c1c27l, df_2011_c1c27l, df_2105_c1c27l, df_2111_c1c27l, 
          df_2205_c1c27l, df_2211_c1c27l]
for df in agg_df_list_au:
    df['RCL_AU_C'] = 0

# %%
col_keep_strip_l
# Out:
# ['ENTIRE_NAME',
#  'CTR_CD',
#  'CTR_TY',
#  'RELEASE_DATE',
#  'ORG',
#  'RCL_A10_C',
#  'RCL_A17_C',
#  'RCL_A2_C',
#  'RCL_A34_C',
#  'RCL_A49_C',
#  'RCL_A64_C',
#  'RCL_A65P_C',
#  'RCL_AU_C',
#  'RCL_BAB_C',
#  'RCL_BA_C',
#  'RCL_BB_C',
#  'RCL_BO_C',
#  'RCL_BMI20_C',
#  'RCL_BMI25_C',
#  'RCL_BMI30_C',
#  'RCL_BMI31P_C',
#  'RCL_BMINR_C',
#  'RCL_BU_C',
#  'RCL_GF_C',
#  'RCL_GM_C',
#  'RCL_GU_C',
#  'RCL_ICU_C',
#  'RCL_HOSPNR_C',
#  'RCL_HOSP_C',
#  'RCL_PTXN_C',
#  'RCL_PTXU_C',
#  'RCL_PTXY_C',
#  'RCL_NOTHOSP_C',
#  'RCL_N_C',
#  'YEAR',
#  'MONTH',
#  'D_OR_L']

# %%
#only keep the columns in the list for each dataframe
df_1207_c1c27l = df_1207_c1c27l[col_keep_strip_l]
df_1301_c1c27l = df_1301_c1c27l[col_keep_strip_l]
df_1307_c1c27l = df_1307_c1c27l[col_keep_strip_l]
df_1401_c1c27l = df_1401_c1c27l[col_keep_strip_l]
df_1406_c1c27l = df_1406_c1c27l[col_keep_strip_l]
df_1412_c1c27l = df_1412_c1c27l[col_keep_strip_l]
df_1506_c1c27l = df_1506_c1c27l[col_keep_strip_l]
df_1512_c1c27l = df_1512_c1c27l[col_keep_strip_l]
df_1606_c1c27l = df_1606_c1c27l[col_keep_strip_l]
df_1701_c1c27l = df_1701_c1c27l[col_keep_strip_l]
df_1707_c1c27l = df_1707_c1c27l[col_keep_strip_l]
df_1711_c1c27l = df_1711_c1c27l[col_keep_strip_l]
df_1808_c1c27l = df_1808_c1c27l[col_keep_strip_l]
df_1811_c1c27l = df_1811_c1c27l[col_keep_strip_l]
df_1905_c1c27l = df_1905_c1c27l[col_keep_strip_l]
df_1911_c1c27l = df_1911_c1c27l[col_keep_strip_l]
df_2006_c1c27l = df_2006_c1c27l[col_keep_strip_l]
df_2011_c1c27l = df_2011_c1c27l[col_keep_strip_l]
df_2105_c1c27l = df_2105_c1c27l[col_keep_strip_l]
df_2111_c1c27l = df_2111_c1c27l[col_keep_strip_l]
df_2205_c1c27l = df_2205_c1c27l[col_keep_strip_l]
df_2211_c1c27l = df_2211_c1c27l[col_keep_strip_l]

# %%
#create a new dataframe list
new_df_list_l = [df_1207_c1c27l,
df_1301_c1c27l,
df_1307_c1c27l,
df_1401_c1c27l,
df_1406_c1c27l,
df_1412_c1c27l,
df_1506_c1c27l,
df_1512_c1c27l,
df_1606_c1c27l,
df_1701_c1c27l,
df_1707_c1c27l,
df_1711_c1c27l,
df_1808_c1c27l,
df_1811_c1c27l,
df_1905_c1c27l,
df_1911_c1c27l,
df_2006_c1c27l,
df_2011_c1c27l,
df_2105_c1c27l,
df_2111_c1c27l,
df_2205_c1c27l,
df_2211_c1c27l]

# %%
print(len(df_1905_c1c27l.columns))
# Out:
# 37

# %%
#concatenate all the dataframes and create one dataframe
df_c1c27l_concat = pd.concat(new_df_list_l)

# %%
df_c1c27l_concat
# Out:
#                                            ENTIRE_NAME  CTR_CD CTR_TY  \
# 0               University of Alabama Hospital (ALUA)    ALUA    TX1
# 1                       Baptist Medical Center (ARBH)    ARBH    TX1
# 2                 Arkansas Children's Hospital (ARCH)    ARCH    TX1
# 3                          UAMS Medical Center (ARUA)    ARUA    TX1
# 4                  Phoenix Children's Hospital (AZCH)    AZCH    TX1
# ..                                                 ...     ...    ...
# 216  University of Virginia Health Sciences Center ...    VAUV    TX1
# 217                                                NaN    ILVA    TX1
# 218                                                NaN    PARH    TX1
# 219                                                NaN    SCPG    TX1
# 220                                                NaN    TXDS    TX1
#
#             RELEASE_DATE       ORG  RCL_A10_C  RCL_A17_C  RCL_A2_C  \
# ...

# %%
#send this concatenated dataframe to a csv
df_c1c27l_concat.to_csv('output/kidney_C1-C2-T7-D_liv.csv')

# %%
#read in the other csv created from the kidney deceased donor concatenated dataframes
df_c1c27d_concat = pd.read_csv('output/kidney_C1-C2-T7-D.csv')

# %%
#drop the Unnamed column
new_df = df_c1c27d_concat.drop(['Unnamed: 0'], axis=1)

# %%
print(len(new_df.columns))
# Out:
# 37

# %%
#rename the columns of the living donor transplant dataframe to match the deceased donor transplant dataframe
df_c1c27l_concat.rename(columns={'RCL_A10_C': 'RCC_A10_C', 'RCL_A17_C': 'RCC_A17_C', 'RCL_A2_C': 'RCC_A2_C', 
                                   'RCL_A34_C': 'RCC_A34_C', 'RCL_A49_C': 'RCC_A49_C', 'RCL_A64_C': 'RCC_A64_C',
                                   'RCL_A65P_C': 'RCC_A65P_C', 'RCL_AU_C': 'RCC_AU_C', 'RCL_BAB_C': 'RCC_BAB_C', 
                                   'RCL_BA_C': 'RCC_BA_C', 'RCL_BB_C': 'RCC_BB_C','RCL_BO_C': 'RCC_BO_C', 
                                   'RCL_BMI20_C': 'RCC_BMI20_C', 'RCL_BMI25_C': 'RCC_BMI25_C', 
                                   'RCL_BMI30_C': 'RCC_BMI30_C', 'RCL_BMI31P_C': 'RCC_BMI31P_C',
                                   'RCL_BMINR_C': 'RCC_BMINR_C', 'RCL_BU_C': 'RCC_BU_C', 'RCL_GF_C': 'RCC_GF_C', 
                                   'RCL_GM_C': 'RCC_GM_C', 'RCL_GU_C': 'RCC_GU_C', 'RCL_ICU_C': 'RCC_ICU_C', 
                                   'RCL_HOSPNR_C': 'RCC_HOSPNR_C', 'RCL_HOSP_C': 'RCC_HOSP_C', 
                                   'RCL_PTXN_C': 'RCC_PTXN_C', 'RCL_PTXU_C': 'RCC_PTXU_C', 
                                   'RCL_PTXY_C': 'RCC_PTXY_C', 'RCL_NOTHOSP_C': 'RCC_NOTHOSP_C', 
                                   'RCL_N_C': 'RCC_N_C'}, inplace=True)

# %%
df_c1c27l_concat.columns
# Out:
# Index(['ENTIRE_NAME', 'CTR_CD', 'CTR_TY', 'RELEASE_DATE', 'ORG', 'RCC_A10_C',
#        'RCC_A17_C', 'RCC_A2_C', 'RCC_A34_C', 'RCC_A49_C', 'RCC_A64_C',
#        'RCC_A65P_C', 'RCC_AU_C', 'RCC_BAB_C', 'RCC_BA_C', 'RCC_BB_C',
#        'RCC_BO_C', 'RCC_BMI20_C', 'RCC_BMI25_C', 'RCC_BMI30_C', 'RCC_BMI31P_C',
#        'RCC_BMINR_C', 'RCC_BU_C', 'RCC_GF_C', 'RCC_GM_C', 'RCC_GU_C',
#        'RCC_ICU_C', 'RCC_HOSPNR_C', 'RCC_HOSP_C', 'RCC_PTXN_C', 'RCC_PTXU_C',
#        'RCC_PTXY_C', 'RCC_NOTHOSP_C', 'RCC_N_C', 'YEAR', 'MONTH', 'D_OR_L'],
#       dtype='object')

# %%
#concatenate the two dataframes with living and deceased donor transplant data
kidney_concat_df = [new_df, df_c1c27l_concat]
kidney_concat = pd.concat(kidney_concat_df)

# %%
kidney_concat
# Out:
#                                            ENTIRE_NAME  CTR_CD CTR_TY  \
# 0                        Children's of Alabama (ALCH)    ALCH    TX1
# 1               University of Alabama Hospital (ALUA)    ALUA    TX1
# 2                       Baptist Medical Center (ARBH)    ARBH    TX1
# 3                 Arkansas Children's Hospital (ARCH)    ARCH    TX1
# 4                          UAMS Medical Center (ARUA)    ARUA    TX1
# ..                                                 ...     ...    ...
# 216  University of Virginia Health Sciences Center ...    VAUV    TX1
# 217                                                NaN    ILVA    TX1
# 218                                                NaN    PARH    TX1
# 219                                                NaN    SCPG    TX1
# 220                                                NaN    TXDS    TX1
#
#             RELEASE_DATE       ORG  RCC_A10_C  RCC_A17_C  RCC_A2_C  \
# ...

# %%
#send the data to a csv
kidney_concat.to_csv('output/kidney_concat.csv')

# %%
#column list and order for other transplant data
col_list = ['CTR_CD', 'CTR_TY', 'RELEASE_DATE', 'ORG', 'RCC_A10_C', 'RCC_A17_C', 'RCC_A2_C', 'RCC_A34_C',
            'RCC_A49_C', 'RCC_BAB_C', 'RCC_BA_C', 'RCC_BB_C', 'RCC_BO_C', 'RCC_BMI20_C', 'RCC_BMI25_C',
            'RCC_BMI30_C', 'RCC_BMINR_C', 'RCC_BU_C', 'RCC_GF_C', 'RCC_GM_C', 'RCC_GU_C', 'RCC_ICU_C',
            'RCC_HOSPNR_C', 'RCC_HOSP_C', 'RCC_PTXN_C', 'RCC_PTXU_C', 'RCC_PTXY_C', 'RCC_NOTHOSP_C', 
            'RCC_TST1A_C', 'RCC_TST1A_R', 'RCC_TST1B_C', 'RCC_TST2_C', 'RCC_TST2_R', 'RCC_TINA_C',
            'RCC_TINA_R', 'RCC_A64_C', 'D_OR_L', 'YEAR', 'MONTH']

# %%
kidney_concat.columns
# Out:
# Index(['ENTIRE_NAME', 'CTR_CD', 'CTR_TY', 'RELEASE_DATE', 'ORG', 'RCC_A10_C',
#        'RCC_A17_C', 'RCC_A2_C', 'RCC_A34_C', 'RCC_A49_C', 'RCC_A64_C',
#        'RCC_A65P_C', 'RCC_AU_C', 'RCC_BAB_C', 'RCC_BA_C', 'RCC_BB_C',
#        'RCC_BO_C', 'RCC_BMI20_C', 'RCC_BMI25_C', 'RCC_BMI30_C', 'RCC_BMI31P_C',
#        'RCC_BMINR_C', 'RCC_BU_C', 'RCC_GF_C', 'RCC_GM_C', 'RCC_GU_C',
#        'RCC_ICU_C', 'RCC_HOSPNR_C', 'RCC_HOSP_C', 'RCC_PTXN_C', 'RCC_PTXU_C',
#        'RCC_PTXY_C', 'RCC_NOTHOSP_C', 'RCC_N_C', 'YEAR', 'MONTH', 'D_OR_L'],
#       dtype='object')

# %%
#new_df = df_c1c27d_concat.drop(['Unnamed: 0'], axis=1)
kidney_concat_final = kidney_concat.drop(['ENTIRE_NAME'], axis=1)

# %%
# Add the following columns and set to zero: 'RCC_TST1A_C', 'RCC_TST1A_R', 'RCC_TST1B_C', 'RCC_TST2_C', 
#'RCC_TST2_R', 'RCC_TINA_C', 'RCC_TINA_R']

kidney_concat_final['RCC_TST1A_C'] = 0

# %%
# df.rename = rename(columns={'RCL_A10_C': 'RCC_A10_C', 'RCL_A17_C': 'RCC_A17_C', 'RCL_A2_C': 'RCC_A2_C', 
#                             'RCL_A34_C': 'RCC_A34_C', 'RCL_A49_C': 'RCC_A49_C',
#                             'RCL_A65P_C': 'RCC_A65P_C', 'RCL_AU_C': 'RCC_AU_C', 'RCL_BAB_C': 'RCC_BAB_C', 
#                             'RCL_BA_C': 'RCC_BA_C', 'RCL_BB_C': 'RCC_BB_C', 'RCL_BO_C': 'RCC_BO_C', 
#                             'RCL_BMI20_C': 'RCC_BMI20_C', 'RCL_BMI25_C': 'RCC_BMI25_C', 'RCL_BMI30_C': 'RCC_BMI30_C', 
#                             'RCL_BMI31P_C': 'RCC_BMI31P_C', 'RCL_BMINR_C': 'RCC_BMINR_C', 
#                             'RCL_BU_C': 'RCC_BU_C', 'RCL_GF_C': 'RCC_GF_C', 'RCL_GM_C': 'RCC_GM_C', 
#                             'RCL_GU_C': 'RCC_GU_C', 'RCL_ICU_C': 'RCC_ICU_C', 'RCL_HOSPNR_C': 'RCC_HOSPNR_C', 
#                             'RCL_HOSP_C': 'RCC_HOSP_C', 'RCL_PTXN_C': 'RCC_PTXN_C', 'RCL_PTXU_C': 'RCC_PTXU_C', 
#                             'RCL_PTXY_C': 'RCC_PTXY_C', 'RCCL_NOTHOSP_C': 'RCC_NOTHOSP_C', 'RCL_TST1_C': 'RCC_TST1_C', 
#                             'RCL_TST1_R': 'RCC_TST1_R', 'RCL_TST1A_C': 'RCC_TST1A_C', 'RCL_TST1A_R': 'RCC_TST1A_R', 
#                             'RCL_TST1B_C': 'RCC_TST1B_C', 'RCL_TST1B_R': 'RCC_TST1B_R', 'RCL_TST2_C': 'RCC_TST2_C', 
#                             'RCL_TST2_R': 'RCC_TST2_R', 'RCL_TST2A_C': 'RCC_TST2A_C', 'RCL_TST2A_R': 'RCC_TST2A_R', 
#                             'RCL_TST2B_C': 'RCC_TST2B_C', 'RCL_TST2B_R': 'RCC_TST2B_R', 'RCL_TST3_C': 'RCC_TST3_C', 
#                             'RCL_TST3_R': 'RCC_TST3_R', 'RCL_ME11_C': 'RCC_ME11_C', 'RCL_ME11_R': 'RCC_ME11_R', 
#                             'RCL_ME15_C': 'RCC_ME15_C', 'RCL_ME15_R': 'RCC_ME15_R', 'RCL_ME21_C': 'RCC_ME21_C', 
#                             'RCL_ME21_R': 'RCC_ME21_R', 'RCL_ME31_C': 'RCC_ME31_C', 'RCL_ME31_R': 'RCC_ME31_R',
#                             'RCL_ME6_C': 'RCC_ME6_C', 'RCL_ME6_R': 'RCC_ME6_R', 'RCL_PE6_C': 'RCC_PE6_C', 
#                             'RCL_PE6_R': 'RCC_PE6_R', 'RCL_PE11_C': 'RCC_PE11_C', 'RCL_PE11_R': 'RCC_PE11_R', 
#                             'RCL_PE15_C': 'RCC_PE15_C', 'RCL_PE15_R': 'RCC_PE15_R', 'RCL_PE21_C': 'RCC_PE21_C', 
#                             'RCL_PE21_R': 'RCC_PE21_R', 'RCL_PE31_C': 'RCC_PE31_C', 'RCL_PE31_R': 'RCC_PE31_R', 
#                             'RCL_TINA_C': 'RCC_TINA_C', 'RCL_TINA_R': 'RCC_TINA_R', 'RCL_N_C': 'RCC_N_C',})
