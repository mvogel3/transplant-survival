# %%
# importing dependencies

import pandas as pd
import os
import re
import calendar
import numpy as np

# %%
# grabbing all the files in the "Resources_HR" directory

excel_files = [file for file in os.listdir("Resources_LI") if not file.startswith("~") and file.lower().endswith(".xls")]

# %%
# checking to see that all files were imported

print(len(excel_files))
# Out:
# 22

# %%
concat=False;
for file in excel_files:
    year_month = re.sub("[^\d]", "", file)
    year = "20"+year_month[0:2]
    month = int(year_month[2:4])
    
    
    if(year in ["2012", "2013", "2014"]):
        sheet_name = "Table 10"
    elif(year in ['2015', '2016', '2017', '2018', '2019', '2020', '2021']):
        sheet_name = "TablesC5-C10 FiguresC1-C12"
    else:
        sheet_name = "TablesC5-C12 Figures C1-C20"
        
    
    survival_df = pd.read_excel(io='Resources_LI/'+file, sheet_name=sheet_name)

        
    if(len(survival_df.index)>0):
        survival_df = survival_df.drop(survival_df.index[0])
   
        
    survival_df_cleaned = pd.DataFrame()
    
    
    
    columns_to_keep = ["Unnamed: 0", ' ctr_cd', 'ctr_ty', 'ENTIRE_NAME', 'CTR_CD', 'CTR_TY', 'RELEASE_DATE', 'ORG', 
                       'GSR_AD_OBS_C1M', 'GSR_AD_OBS_C1Y', 'GSR_AD_OBS_C3Y', 
                       'GSR_AD_ACT_C1M', 'GSR_AD_ACT_C1Y', 'GSR_AD_ACT_C3Y', 
                       'GSR_AD_ADJ_C1M', 'GSR_AD_ADJ_C1Y', 'GSR_AD_ADJ_C3Y',
                       'GSR_AD_EXP_C1M', 'GSR_AD_EXP_C1Y', 'GSR_AD_EXP_C3Y', 
                       'GSR_AD_N_C1M', 'GSR_AD_N_C1Y', 'GSR_AD_N_C3Y', 
                       'GSR_P0_OBS_C1M', 'GSR_P0_OBS_C1Y', 'GSR_P0_OBS_C3Y',
                       'GSR_P0_ACT_C1M', 'GSR_P0_ACT_C1Y', 'GSR_P0_ACT_C1Y', 
                       'GSR_P0_ADJ_C1M', 'GSR_P0_ADJ_C1Y', 'GSR_P0_ADJ_C3Y',
                       'GSR_P0_EXP_C1M', 'GSR_P0_EXP_C1Y', 'GSR_P0_EXP_C3Y', 
                       'GSR_P0_N_C1M', 'GSR_P0_N_C1Y', 'GSR_P0_C3Y']
    
    
    for column in columns_to_keep:
        if column in survival_df:
            survival_df_cleaned[column]=survival_df[column]
        elif column+" " in survival_df:
            survival_df_cleaned[column]=survival_df[column+" "]
        elif " "+column in survival_df:
            survival_df_cleaned[column]=survival_df[" "+column]
        elif " "+column+" " in survival_df:
            survival_df_cleaned[column]=survival_df[" "+column+" "]

    
    survival_df_cleaned["YEAR"]=year
    survival_df_cleaned["MONTH"]=month

    if(concat==True):
        merged_survival_df= pd.concat([merged_survival_df, survival_df_cleaned], axis=0)

    else:
        merged_survival_df=survival_df_cleaned
        
        concat=True

# %%
merged_survival_df
# Out:
#                                            ENTIRE_NAME CTR_CD CTR_TY  \
# 1                         Children's of Alabama (ALCH)   ALCH    TX1
# 2                University of Alabama Hospital (ALUA)   ALUA    TX1
# 3                           UAMS Medical Center (ARUA)   ARUA    TX1
# 4                   Phoenix Children's Hospital (AZCH)   AZCH    TX1
# 5      Banner-University Medical Center Phoenix (AZGS)   AZGS    TX1
# ..                                                 ...    ...    ...
# 140     University of Washington Medical Center (WAUW)   WAUW    TX1
# 141            Children's Hospital of Wisconsin (WICH)   WICH    TX1
# 142        Froedtert Memorial Lutheran Hospital (WISE)   WISE    TX1
# 143            Aurora St. Luke's Medical Center (WISL)   WISL    TX1
# 144  University of Wisconsin Hospital and Clinics (...   WIUW    TX1
#
#             RELEASE_DATE ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1    2021-01-04 18:00:00  LI            NaN            NaN            NaN
# 2    2021-01-04 18:00:00  LI             13             20             41
# 3    2021-01-04 18:00:00  LI              1              4              8
# 4    2021-01-04 18:00:00  LI            NaN            NaN            NaN
# 5    2021-01-04 18:00:00  LI             10             29             28
# ..                   ...  ..            ...            ...            ...
# 140  2022-07-06 19:00:00  LI              8             14             14
# 141  2022-07-06 19:00:00  LI            NaN            NaN            NaN
# 142  2022-07-06 19:00:00  LI              3              5              6
# 143  2022-07-06 19:00:00  LI              2              3              8
# 144  2022-07-06 19:00:00  LI             10             20             32
#
#     GSR_AD_ACT_C1M GSR_AD_ACT_C1Y  ... GSR_P0_EXP_C1M GSR_P0_EXP_C1Y  \
# 1              NaN            NaN  ...       0.554474        0.92971
# 2        95.422535      92.721906  ...            NaN            NaN
# 3        98.901099      95.194139  ...            NaN            NaN
# 4              NaN            NaN  ...       0.906557       1.549487
# 5        96.478873      88.596449  ...            NaN            NaN
# ..             ...            ...  ...            ...            ...
# 140      96.718873      94.042122  ...            NaN            NaN
# 141            NaN            NaN  ...        0.38202       0.607775
# 142       94.98827      91.144356  ...            NaN            NaN
# 143      96.078431      93.735055  ...            NaN            NaN
# 144      95.422146      89.621382  ...       0.235003       0.369289
#
#     GSR_P0_EXP_C3Y GSR_P0_N_C1M GSR_P0_N_C1Y  YEAR MONTH Unnamed: 0  ctr_cd  \
# 1         1.376872           14           14  2020    11        NaN     NaN
# 2              NaN          NaN          NaN  2020    11        NaN     NaN
# 3              NaN          NaN          NaN  2020    11        NaN     NaN
# 4         1.340967           18           18  2020    11        NaN     NaN
# 5              NaN          NaN          NaN  2020    11        NaN     NaN
# ..             ...          ...          ...   ...   ...        ...     ...
# 140            NaN          NaN          NaN  2022     5        NaN     NaN
# 141       1.668393           10           10  2022     5        NaN     NaN
# 142            NaN          NaN          NaN  2022     5        NaN     NaN
# 143            NaN          NaN          NaN  2022     5        NaN     NaN
# 144        0.54188            5            5  2022     5        NaN     NaN
#
#     ctr_ty
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# ..     ...
# 140    NaN
# 141    NaN
# 142    NaN
# 143    NaN
# 144    NaN
#
# [3120 rows x 38 columns]

# %%
column_adding = merged_survival_df.copy()

# df['b'] = df['b'].fillna(df['a'])

column_adding['ENTIRE_NAME'] = column_adding['ENTIRE_NAME'].fillna(column_adding['Unnamed: 0'])

# column_adding['ENTIRE_NAME'] = column_adding['ENTIRE_NAME'] + column_adding['Unnamed: 0']

column_adding
# Out:
#                                            ENTIRE_NAME CTR_CD CTR_TY  \
# 1                         Children's of Alabama (ALCH)   ALCH    TX1
# 2                University of Alabama Hospital (ALUA)   ALUA    TX1
# 3                           UAMS Medical Center (ARUA)   ARUA    TX1
# 4                   Phoenix Children's Hospital (AZCH)   AZCH    TX1
# 5      Banner-University Medical Center Phoenix (AZGS)   AZGS    TX1
# ..                                                 ...    ...    ...
# 140     University of Washington Medical Center (WAUW)   WAUW    TX1
# 141            Children's Hospital of Wisconsin (WICH)   WICH    TX1
# 142        Froedtert Memorial Lutheran Hospital (WISE)   WISE    TX1
# 143            Aurora St. Luke's Medical Center (WISL)   WISL    TX1
# 144  University of Wisconsin Hospital and Clinics (...   WIUW    TX1
#
#             RELEASE_DATE ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1    2021-01-04 18:00:00  LI            NaN            NaN            NaN
# 2    2021-01-04 18:00:00  LI             13             20             41
# 3    2021-01-04 18:00:00  LI              1              4              8
# 4    2021-01-04 18:00:00  LI            NaN            NaN            NaN
# 5    2021-01-04 18:00:00  LI             10             29             28
# ..                   ...  ..            ...            ...            ...
# 140  2022-07-06 19:00:00  LI              8             14             14
# 141  2022-07-06 19:00:00  LI            NaN            NaN            NaN
# 142  2022-07-06 19:00:00  LI              3              5              6
# 143  2022-07-06 19:00:00  LI              2              3              8
# 144  2022-07-06 19:00:00  LI             10             20             32
#
#     GSR_AD_ACT_C1M GSR_AD_ACT_C1Y  ... GSR_P0_EXP_C1M GSR_P0_EXP_C1Y  \
# 1              NaN            NaN  ...       0.554474        0.92971
# 2        95.422535      92.721906  ...            NaN            NaN
# 3        98.901099      95.194139  ...            NaN            NaN
# 4              NaN            NaN  ...       0.906557       1.549487
# 5        96.478873      88.596449  ...            NaN            NaN
# ..             ...            ...  ...            ...            ...
# 140      96.718873      94.042122  ...            NaN            NaN
# 141            NaN            NaN  ...        0.38202       0.607775
# 142       94.98827      91.144356  ...            NaN            NaN
# 143      96.078431      93.735055  ...            NaN            NaN
# 144      95.422146      89.621382  ...       0.235003       0.369289
#
#     GSR_P0_EXP_C3Y GSR_P0_N_C1M GSR_P0_N_C1Y  YEAR MONTH Unnamed: 0  ctr_cd  \
# 1         1.376872           14           14  2020    11        NaN     NaN
# 2              NaN          NaN          NaN  2020    11        NaN     NaN
# 3              NaN          NaN          NaN  2020    11        NaN     NaN
# 4         1.340967           18           18  2020    11        NaN     NaN
# 5              NaN          NaN          NaN  2020    11        NaN     NaN
# ..             ...          ...          ...   ...   ...        ...     ...
# 140            NaN          NaN          NaN  2022     5        NaN     NaN
# 141       1.668393           10           10  2022     5        NaN     NaN
# 142            NaN          NaN          NaN  2022     5        NaN     NaN
# 143            NaN          NaN          NaN  2022     5        NaN     NaN
# 144        0.54188            5            5  2022     5        NaN     NaN
#
#     ctr_ty
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# ..     ...
# 140    NaN
# 141    NaN
# 142    NaN
# 143    NaN
# 144    NaN
#
# [3120 rows x 38 columns]

# %%
column_adding['YEAR'].unique()
# Out:
# array(['2020', '2021', '2019', '2014', '2013', '2012', '2015', '2018',
#        '2016', '2022', '2017'], dtype=object)

# %%
# df.loc[df['column_name'].isin(some_values)]

column_adding.loc[column_adding['YEAR']=='2012']
# Out:
#                                            ENTIRE_NAME CTR_CD CTR_TY  \
# 1               University of Alabama Hospital (ALUA)     NaN    NaN
# 2                 Arkansas Children's Hospital (ARCH)     NaN    NaN
# 3                          UAMS Medical Center (ARUA)     NaN    NaN
# 4         Banner Good Samaritan Medical Center (AZGS)     NaN    NaN
# 5                         Mayo Clinic Hospital (AZMC)     NaN    NaN
# ..                                                 ...    ...    ...
# 131    University of Washington Medical Center (WAUW)     NaN    NaN
# 132           Children's Hospital of Wisconsin (WICH)     NaN    NaN
# 133       Froedtert Memorial Lutheran Hospital (WISE)     NaN    NaN
# 134           Aurora St. Luke's Medical Center (WISL)     NaN    NaN
# 135  University of Wisconsin Hospital and Clinics (...    NaN    NaN
#
#      RELEASE_DATE      ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1     2012/07/13    Liver              8             29             38
# 2     2012/07/13    Liver
# 3     2012/07/13    Liver              3              5              8
# 4     2012/07/13    Liver              5             20             20
# 5     2012/07/13    Liver              8             13             25
# ..            ...      ...            ...            ...            ...
# 131   2012/07/13    Liver              5             15             43
# 132   2012/07/13    Liver
# 133   2012/07/13    Liver              0              4             20
# 134   2012/07/13    Liver              2              6             15
# 135   2012/07/13    Liver              5             17             41
#
#     GSR_AD_ACT_C1M GSR_AD_ACT_C1Y  ... GSR_P0_EXP_C1M GSR_P0_EXP_C1Y  \
# 1            96.76          87.65  ...          0.99           1.56
# 2                                  ...          0.02           0.03
# 3            95.38          92.31  ...
# 4            96.06          83.63  ...
# 5            93.16          88.63  ...
# ..             ...            ...  ...            ...            ...
# 131          97.19          91.11  ...
# 132                                ...          0.32           0.43
# 133            100          88.78  ...
# 134          96.23          88.12  ...
# 135          97.34          90.46  ...          1.63           2.49
#
#     GSR_P0_EXP_C3Y GSR_P0_N_C1M GSR_P0_N_C1Y  YEAR MONTH  \
# 1            3.72           17           17   2012     7
# 2                            1            1   2012     7
# 3                                             2012     7
# 4                                             2012     7
# 5                                             2012     7
# ..             ...          ...          ...   ...   ...
# 131                                           2012     7
# 132          3.10            6            6   2012     7
# 133                                           2012     7
# 134                                           2012     7
# 135          1.39           13           13   2012     7
#
#                                             Unnamed: 0  ctr_cd ctr_ty
# 1               University of Alabama Hospital (ALUA)    ALUA    TX1
# 2                 Arkansas Children's Hospital (ARCH)    ARCH    TX1
# 3                          UAMS Medical Center (ARUA)    ARUA    TX1
# 4         Banner Good Samaritan Medical Center (AZGS)    AZGS    TX1
# 5                         Mayo Clinic Hospital (AZMC)    AZMC    TX1
# ..                                                 ...     ...    ...
# 131    University of Washington Medical Center (WAUW)    WAUW    TX1
# 132           Children's Hospital of Wisconsin (WICH)    WICH    TX1
# 133       Froedtert Memorial Lutheran Hospital (WISE)    WISE    TX1
# 134           Aurora St. Luke's Medical Center (WISL)    WISL    TX1
# 135  University of Wisconsin Hospital and Clinics (...   WIUW    TX1
#
# [135 rows x 38 columns]

# %%
column_adding.columns
# Out:
# Index(['ENTIRE_NAME', 'CTR_CD', 'CTR_TY', 'RELEASE_DATE', 'ORG',
#        'GSR_AD_OBS_C1M', 'GSR_AD_OBS_C1Y', 'GSR_AD_OBS_C3Y', 'GSR_AD_ACT_C1M',
#        'GSR_AD_ACT_C1Y', 'GSR_AD_ACT_C3Y', 'GSR_AD_ADJ_C1M', 'GSR_AD_ADJ_C1Y',
#        'GSR_AD_ADJ_C3Y', 'GSR_AD_EXP_C1M', 'GSR_AD_EXP_C1Y', 'GSR_AD_EXP_C3Y',
#        'GSR_AD_N_C1M', 'GSR_AD_N_C1Y', 'GSR_AD_N_C3Y', 'GSR_P0_OBS_C1M',
#        'GSR_P0_OBS_C1Y', 'GSR_P0_OBS_C3Y', 'GSR_P0_ACT_C1M', 'GSR_P0_ACT_C1Y',
#        'GSR_P0_ADJ_C1M', 'GSR_P0_ADJ_C1Y', 'GSR_P0_ADJ_C3Y', 'GSR_P0_EXP_C1M',
#        'GSR_P0_EXP_C1Y', 'GSR_P0_EXP_C3Y', 'GSR_P0_N_C1M', 'GSR_P0_N_C1Y',
#        'YEAR', 'MONTH', 'Unnamed: 0', ' ctr_cd', 'ctr_ty'],
#       dtype='object')

# %%
# column_adding['ENTIRE_NAME'] = column_adding['ENTIRE_NAME'].fillna(column_adding['Unnamed: 0'])
column_adding['CTR_CD'] = column_adding['CTR_CD'].fillna(column_adding[' ctr_cd'])
column_adding['CTR_TY'] = column_adding['CTR_TY'].fillna(column_adding['ctr_ty'])

column_adding
# Out:
#                                            ENTIRE_NAME CTR_CD CTR_TY  \
# 1                         Children's of Alabama (ALCH)   ALCH    TX1
# 2                University of Alabama Hospital (ALUA)   ALUA    TX1
# 3                           UAMS Medical Center (ARUA)   ARUA    TX1
# 4                   Phoenix Children's Hospital (AZCH)   AZCH    TX1
# 5      Banner-University Medical Center Phoenix (AZGS)   AZGS    TX1
# ..                                                 ...    ...    ...
# 140     University of Washington Medical Center (WAUW)   WAUW    TX1
# 141            Children's Hospital of Wisconsin (WICH)   WICH    TX1
# 142        Froedtert Memorial Lutheran Hospital (WISE)   WISE    TX1
# 143            Aurora St. Luke's Medical Center (WISL)   WISL    TX1
# 144  University of Wisconsin Hospital and Clinics (...   WIUW    TX1
#
#             RELEASE_DATE ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1    2021-01-04 18:00:00  LI            NaN            NaN            NaN
# 2    2021-01-04 18:00:00  LI             13             20             41
# 3    2021-01-04 18:00:00  LI              1              4              8
# 4    2021-01-04 18:00:00  LI            NaN            NaN            NaN
# 5    2021-01-04 18:00:00  LI             10             29             28
# ..                   ...  ..            ...            ...            ...
# 140  2022-07-06 19:00:00  LI              8             14             14
# 141  2022-07-06 19:00:00  LI            NaN            NaN            NaN
# 142  2022-07-06 19:00:00  LI              3              5              6
# 143  2022-07-06 19:00:00  LI              2              3              8
# 144  2022-07-06 19:00:00  LI             10             20             32
#
#     GSR_AD_ACT_C1M GSR_AD_ACT_C1Y  ... GSR_P0_EXP_C1M GSR_P0_EXP_C1Y  \
# 1              NaN            NaN  ...       0.554474        0.92971
# 2        95.422535      92.721906  ...            NaN            NaN
# 3        98.901099      95.194139  ...            NaN            NaN
# 4              NaN            NaN  ...       0.906557       1.549487
# 5        96.478873      88.596449  ...            NaN            NaN
# ..             ...            ...  ...            ...            ...
# 140      96.718873      94.042122  ...            NaN            NaN
# 141            NaN            NaN  ...        0.38202       0.607775
# 142       94.98827      91.144356  ...            NaN            NaN
# 143      96.078431      93.735055  ...            NaN            NaN
# 144      95.422146      89.621382  ...       0.235003       0.369289
#
#     GSR_P0_EXP_C3Y GSR_P0_N_C1M GSR_P0_N_C1Y  YEAR MONTH Unnamed: 0  ctr_cd  \
# 1         1.376872           14           14  2020    11        NaN     NaN
# 2              NaN          NaN          NaN  2020    11        NaN     NaN
# 3              NaN          NaN          NaN  2020    11        NaN     NaN
# 4         1.340967           18           18  2020    11        NaN     NaN
# 5              NaN          NaN          NaN  2020    11        NaN     NaN
# ..             ...          ...          ...   ...   ...        ...     ...
# 140            NaN          NaN          NaN  2022     5        NaN     NaN
# 141       1.668393           10           10  2022     5        NaN     NaN
# 142            NaN          NaN          NaN  2022     5        NaN     NaN
# 143            NaN          NaN          NaN  2022     5        NaN     NaN
# 144        0.54188            5            5  2022     5        NaN     NaN
#
#     ctr_ty
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# ..     ...
# 140    NaN
# 141    NaN
# 142    NaN
# 143    NaN
# 144    NaN
#
# [3120 rows x 38 columns]

# %%
column_adding.loc[column_adding['YEAR']=='2021']
# Out:
#                                            ENTIRE_NAME CTR_CD CTR_TY  \
# 1                         Children's of Alabama (ALCH)   ALCH    TX1
# 2                University of Alabama Hospital (ALUA)   ALUA    TX1
# 3                           UAMS Medical Center (ARUA)   ARUA    TX1
# 4                   Phoenix Children's Hospital (AZCH)   AZCH    TX1
# 5      Banner-University Medical Center Phoenix (AZGS)   AZGS    TX1
# ..                                                 ...    ...    ...
# 141     University of Washington Medical Center (WAUW)   WAUW    TX1
# 142            Children's Hospital of Wisconsin (WICH)   WICH    TX1
# 143        Froedtert Memorial Lutheran Hospital (WISE)   WISE    TX1
# 144            Aurora St. Luke's Medical Center (WISL)   WISL    TX1
# 145  University of Wisconsin Hospital and Clinics (...   WIUW    TX1
#
#             RELEASE_DATE ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1    2022-01-06 18:00:00  LI            NaN            NaN            NaN
# 2    2022-01-06 18:00:00  LI              7             14             47
# 3    2022-01-06 18:00:00  LI              1              4              5
# 4    2022-01-06 18:00:00  LI            NaN            NaN            NaN
# 5    2022-01-06 18:00:00  LI              8             21             38
# ..                   ...  ..            ...            ...            ...
# 141  2021-07-06 19:00:00  LI              8             12             19
# 142  2021-07-06 19:00:00  LI            NaN            NaN            NaN
# 143  2021-07-06 19:00:00  LI              2              3              9
# 144  2021-07-06 19:00:00  LI              1              2              9
# 145  2021-07-06 19:00:00  LI              6             14             43
#
#     GSR_AD_ACT_C1M GSR_AD_ACT_C1Y  ... GSR_P0_EXP_C1M GSR_P0_EXP_C1Y  \
# 1              NaN            NaN  ...       0.372201       0.562681
# 2        96.909643      92.977108  ...            NaN            NaN
# 3        98.717949      93.923204  ...            NaN            NaN
# 4              NaN            NaN  ...       0.527218        0.94711
# 5        96.727805      88.951766  ...            NaN            NaN
# ..             ...            ...  ...            ...            ...
# 141      96.105987      93.838507  ...            NaN            NaN
# 142            NaN            NaN  ...        0.42777       0.665042
# 143      96.319229      94.269884  ...            NaN            NaN
# 144      98.214286       96.12462  ...            NaN            NaN
# 145      97.276995      92.819613  ...       0.076965        0.10046
#
#     GSR_P0_EXP_C3Y GSR_P0_N_C1M GSR_P0_N_C1Y  YEAR MONTH Unnamed: 0  ctr_cd  \
# 1         1.547113            9            9  2021    11        NaN     NaN
# 2              NaN          NaN          NaN  2021    11        NaN     NaN
# 3              NaN          NaN          NaN  2021    11        NaN     NaN
# 4         1.758707           12           12  2021    11        NaN     NaN
# 5              NaN          NaN          NaN  2021    11        NaN     NaN
# ..             ...          ...          ...   ...   ...        ...     ...
# 141            NaN          NaN          NaN  2021     5        NaN     NaN
# 142       3.077728           11           11  2021     5        NaN     NaN
# 143            NaN          NaN          NaN  2021     5        NaN     NaN
# 144            NaN          NaN          NaN  2021     5        NaN     NaN
# 145       0.825289            2            2  2021     5        NaN     NaN
#
#     ctr_ty
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# ..     ...
# 141    NaN
# 142    NaN
# 143    NaN
# 144    NaN
# 145    NaN
#
# [292 rows x 38 columns]

# %%
survival_final = column_adding.drop(columns=['Unnamed: 0', ' ctr_cd', 'ctr_ty'])

survival_final
# Out:
#                                            ENTIRE_NAME CTR_CD CTR_TY  \
# 1                         Children's of Alabama (ALCH)   ALCH    TX1
# 2                University of Alabama Hospital (ALUA)   ALUA    TX1
# 3                           UAMS Medical Center (ARUA)   ARUA    TX1
# 4                   Phoenix Children's Hospital (AZCH)   AZCH    TX1
# 5      Banner-University Medical Center Phoenix (AZGS)   AZGS    TX1
# ..                                                 ...    ...    ...
# 140     University of Washington Medical Center (WAUW)   WAUW    TX1
# 141            Children's Hospital of Wisconsin (WICH)   WICH    TX1
# 142        Froedtert Memorial Lutheran Hospital (WISE)   WISE    TX1
# 143            Aurora St. Luke's Medical Center (WISL)   WISL    TX1
# 144  University of Wisconsin Hospital and Clinics (...   WIUW    TX1
#
#             RELEASE_DATE ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1    2021-01-04 18:00:00  LI            NaN            NaN            NaN
# 2    2021-01-04 18:00:00  LI             13             20             41
# 3    2021-01-04 18:00:00  LI              1              4              8
# 4    2021-01-04 18:00:00  LI            NaN            NaN            NaN
# 5    2021-01-04 18:00:00  LI             10             29             28
# ..                   ...  ..            ...            ...            ...
# 140  2022-07-06 19:00:00  LI              8             14             14
# 141  2022-07-06 19:00:00  LI            NaN            NaN            NaN
# 142  2022-07-06 19:00:00  LI              3              5              6
# 143  2022-07-06 19:00:00  LI              2              3              8
# 144  2022-07-06 19:00:00  LI             10             20             32
#
#     GSR_AD_ACT_C1M GSR_AD_ACT_C1Y  ... GSR_P0_ADJ_C1M GSR_P0_ADJ_C1Y  \
# 1              NaN            NaN  ...      96.051354      93.107823
# 2        95.422535      92.721906  ...            NaN            NaN
# 3        98.901099      95.194139  ...            NaN            NaN
# 4              NaN            NaN  ...      95.098189      91.485857
# 5        96.478873      88.596449  ...            NaN            NaN
# ..             ...            ...  ...            ...            ...
# 140      96.718873      94.042122  ...            NaN            NaN
# 141            NaN            NaN  ...      96.258116      92.433791
# 142       94.98827      91.144356  ...            NaN            NaN
# 143      96.078431      93.735055  ...            NaN            NaN
# 144      95.422146      89.621382  ...      95.441178        90.3541
#
#     GSR_P0_ADJ_C3Y GSR_P0_EXP_C1M GSR_P0_EXP_C1Y GSR_P0_EXP_C3Y GSR_P0_N_C1M  \
# 1        88.506536       0.554474        0.92971       1.376872           14
# 2              NaN            NaN            NaN            NaN          NaN
# 3              NaN            NaN            NaN            NaN          NaN
# 4        88.506536       0.906557       1.549487       1.340967           18
# 5              NaN            NaN            NaN            NaN          NaN
# ..             ...            ...            ...            ...          ...
# 140            NaN            NaN            NaN            NaN          NaN
# 141      89.029182        0.38202       0.607775       1.668393           10
# 142            NaN            NaN            NaN            NaN          NaN
# 143            NaN            NaN            NaN            NaN          NaN
# 144      89.467743       0.235003       0.369289        0.54188            5
#
#     GSR_P0_N_C1Y  YEAR MONTH
# 1             14  2020    11
# 2            NaN  2020    11
# 3            NaN  2020    11
# 4             18  2020    11
# 5            NaN  2020    11
# ..           ...   ...   ...
# 140          NaN  2022     5
# 141           10  2022     5
# 142          NaN  2022     5
# 143          NaN  2022     5
# 144            5  2022     5
#
# [3120 rows x 35 columns]

# %%
first_column = survival_final.pop('ENTIRE_NAME')
second_column = survival_final.pop('CTR_CD')
third_column = survival_final.pop('CTR_TY')

survival_final.insert(0, 'ENTIRE_NAME', first_column)
survival_final.insert(1, 'CTR_CD', second_column)
survival_final.insert(2, 'CTR_TY', third_column)

survival_final
# Out:
#                                            ENTIRE_NAME CTR_CD CTR_TY  \
# 1                         Children's of Alabama (ALCH)   ALCH    TX1
# 2                University of Alabama Hospital (ALUA)   ALUA    TX1
# 3                           UAMS Medical Center (ARUA)   ARUA    TX1
# 4                   Phoenix Children's Hospital (AZCH)   AZCH    TX1
# 5      Banner-University Medical Center Phoenix (AZGS)   AZGS    TX1
# ..                                                 ...    ...    ...
# 140     University of Washington Medical Center (WAUW)   WAUW    TX1
# 141            Children's Hospital of Wisconsin (WICH)   WICH    TX1
# 142        Froedtert Memorial Lutheran Hospital (WISE)   WISE    TX1
# 143            Aurora St. Luke's Medical Center (WISL)   WISL    TX1
# 144  University of Wisconsin Hospital and Clinics (...   WIUW    TX1
#
#             RELEASE_DATE ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1    2021-01-04 18:00:00  LI            NaN            NaN            NaN
# 2    2021-01-04 18:00:00  LI             13             20             41
# 3    2021-01-04 18:00:00  LI              1              4              8
# 4    2021-01-04 18:00:00  LI            NaN            NaN            NaN
# 5    2021-01-04 18:00:00  LI             10             29             28
# ..                   ...  ..            ...            ...            ...
# 140  2022-07-06 19:00:00  LI              8             14             14
# 141  2022-07-06 19:00:00  LI            NaN            NaN            NaN
# 142  2022-07-06 19:00:00  LI              3              5              6
# 143  2022-07-06 19:00:00  LI              2              3              8
# 144  2022-07-06 19:00:00  LI             10             20             32
#
#     GSR_AD_ACT_C1M GSR_AD_ACT_C1Y  ... GSR_P0_ADJ_C1M GSR_P0_ADJ_C1Y  \
# 1              NaN            NaN  ...      96.051354      93.107823
# 2        95.422535      92.721906  ...            NaN            NaN
# 3        98.901099      95.194139  ...            NaN            NaN
# 4              NaN            NaN  ...      95.098189      91.485857
# 5        96.478873      88.596449  ...            NaN            NaN
# ..             ...            ...  ...            ...            ...
# 140      96.718873      94.042122  ...            NaN            NaN
# 141            NaN            NaN  ...      96.258116      92.433791
# 142       94.98827      91.144356  ...            NaN            NaN
# 143      96.078431      93.735055  ...            NaN            NaN
# 144      95.422146      89.621382  ...      95.441178        90.3541
#
#     GSR_P0_ADJ_C3Y GSR_P0_EXP_C1M GSR_P0_EXP_C1Y GSR_P0_EXP_C3Y GSR_P0_N_C1M  \
# 1        88.506536       0.554474        0.92971       1.376872           14
# 2              NaN            NaN            NaN            NaN          NaN
# 3              NaN            NaN            NaN            NaN          NaN
# 4        88.506536       0.906557       1.549487       1.340967           18
# 5              NaN            NaN            NaN            NaN          NaN
# ..             ...            ...            ...            ...          ...
# 140            NaN            NaN            NaN            NaN          NaN
# 141      89.029182        0.38202       0.607775       1.668393           10
# 142            NaN            NaN            NaN            NaN          NaN
# 143            NaN            NaN            NaN            NaN          NaN
# 144      89.467743       0.235003       0.369289        0.54188            5
#
#     GSR_P0_N_C1Y  YEAR MONTH
# 1             14  2020    11
# 2            NaN  2020    11
# 3            NaN  2020    11
# 4             18  2020    11
# 5            NaN  2020    11
# ..           ...   ...   ...
# 140          NaN  2022     5
# 141           10  2022     5
# 142          NaN  2022     5
# 143          NaN  2022     5
# 144            5  2022     5
#
# [3120 rows x 35 columns]

# %%
survival_final = survival_final.replace(r'^\s*$', np.nan, regex=True)

survival_final
# Out:
#                                            ENTIRE_NAME CTR_CD CTR_TY  \
# 1                         Children's of Alabama (ALCH)   ALCH    TX1
# 2                University of Alabama Hospital (ALUA)   ALUA    TX1
# 3                           UAMS Medical Center (ARUA)   ARUA    TX1
# 4                   Phoenix Children's Hospital (AZCH)   AZCH    TX1
# 5      Banner-University Medical Center Phoenix (AZGS)   AZGS    TX1
# ..                                                 ...    ...    ...
# 140     University of Washington Medical Center (WAUW)   WAUW    TX1
# 141            Children's Hospital of Wisconsin (WICH)   WICH    TX1
# 142        Froedtert Memorial Lutheran Hospital (WISE)   WISE    TX1
# 143            Aurora St. Luke's Medical Center (WISL)   WISL    TX1
# 144  University of Wisconsin Hospital and Clinics (...   WIUW    TX1
#
#             RELEASE_DATE ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1    2021-01-04 18:00:00  LI            NaN            NaN            NaN
# 2    2021-01-04 18:00:00  LI             13             20             41
# 3    2021-01-04 18:00:00  LI              1              4              8
# 4    2021-01-04 18:00:00  LI            NaN            NaN            NaN
# 5    2021-01-04 18:00:00  LI             10             29             28
# ..                   ...  ..            ...            ...            ...
# 140  2022-07-06 19:00:00  LI              8             14             14
# 141  2022-07-06 19:00:00  LI            NaN            NaN            NaN
# 142  2022-07-06 19:00:00  LI              3              5              6
# 143  2022-07-06 19:00:00  LI              2              3              8
# 144  2022-07-06 19:00:00  LI             10             20             32
#
#     GSR_AD_ACT_C1M GSR_AD_ACT_C1Y  ... GSR_P0_ADJ_C1M GSR_P0_ADJ_C1Y  \
# 1              NaN            NaN  ...      96.051354      93.107823
# 2        95.422535      92.721906  ...            NaN            NaN
# 3        98.901099      95.194139  ...            NaN            NaN
# 4              NaN            NaN  ...      95.098189      91.485857
# 5        96.478873      88.596449  ...            NaN            NaN
# ..             ...            ...  ...            ...            ...
# 140      96.718873      94.042122  ...            NaN            NaN
# 141            NaN            NaN  ...      96.258116      92.433791
# 142       94.98827      91.144356  ...            NaN            NaN
# 143      96.078431      93.735055  ...            NaN            NaN
# 144      95.422146      89.621382  ...      95.441178        90.3541
#
#     GSR_P0_ADJ_C3Y GSR_P0_EXP_C1M GSR_P0_EXP_C1Y GSR_P0_EXP_C3Y GSR_P0_N_C1M  \
# 1        88.506536       0.554474        0.92971       1.376872           14
# 2              NaN            NaN            NaN            NaN          NaN
# 3              NaN            NaN            NaN            NaN          NaN
# 4        88.506536       0.906557       1.549487       1.340967           18
# 5              NaN            NaN            NaN            NaN          NaN
# ..             ...            ...            ...            ...          ...
# 140            NaN            NaN            NaN            NaN          NaN
# 141      89.029182        0.38202       0.607775       1.668393           10
# 142            NaN            NaN            NaN            NaN          NaN
# 143            NaN            NaN            NaN            NaN          NaN
# 144      89.467743       0.235003       0.369289        0.54188            5
#
#     GSR_P0_N_C1Y  YEAR MONTH
# 1             14  2020    11
# 2            NaN  2020    11
# 3            NaN  2020    11
# 4             18  2020    11
# 5            NaN  2020    11
# ..           ...   ...   ...
# 140          NaN  2022     5
# 141           10  2022     5
# 142          NaN  2022     5
# 143          NaN  2022     5
# 144            5  2022     5
#
# [3120 rows x 35 columns]

# %%
survival_final = survival_final.fillna(0)

survival_final
# Out:
#                                            ENTIRE_NAME CTR_CD CTR_TY  \
# 1                         Children's of Alabama (ALCH)   ALCH    TX1
# 2                University of Alabama Hospital (ALUA)   ALUA    TX1
# 3                           UAMS Medical Center (ARUA)   ARUA    TX1
# 4                   Phoenix Children's Hospital (AZCH)   AZCH    TX1
# 5      Banner-University Medical Center Phoenix (AZGS)   AZGS    TX1
# ..                                                 ...    ...    ...
# 140     University of Washington Medical Center (WAUW)   WAUW    TX1
# 141            Children's Hospital of Wisconsin (WICH)   WICH    TX1
# 142        Froedtert Memorial Lutheran Hospital (WISE)   WISE    TX1
# 143            Aurora St. Luke's Medical Center (WISL)   WISL    TX1
# 144  University of Wisconsin Hospital and Clinics (...   WIUW    TX1
#
#             RELEASE_DATE ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1    2021-01-04 18:00:00  LI              0              0              0
# 2    2021-01-04 18:00:00  LI             13             20             41
# 3    2021-01-04 18:00:00  LI              1              4              8
# 4    2021-01-04 18:00:00  LI              0              0              0
# 5    2021-01-04 18:00:00  LI             10             29             28
# ..                   ...  ..            ...            ...            ...
# 140  2022-07-06 19:00:00  LI              8             14             14
# 141  2022-07-06 19:00:00  LI              0              0              0
# 142  2022-07-06 19:00:00  LI              3              5              6
# 143  2022-07-06 19:00:00  LI              2              3              8
# 144  2022-07-06 19:00:00  LI             10             20             32
#
#     GSR_AD_ACT_C1M GSR_AD_ACT_C1Y  ... GSR_P0_ADJ_C1M GSR_P0_ADJ_C1Y  \
# 1                0              0  ...      96.051354      93.107823
# 2        95.422535      92.721906  ...              0              0
# 3        98.901099      95.194139  ...              0              0
# 4                0              0  ...      95.098189      91.485857
# 5        96.478873      88.596449  ...              0              0
# ..             ...            ...  ...            ...            ...
# 140      96.718873      94.042122  ...              0              0
# 141              0              0  ...      96.258116      92.433791
# 142       94.98827      91.144356  ...              0              0
# 143      96.078431      93.735055  ...              0              0
# 144      95.422146      89.621382  ...      95.441178        90.3541
#
#     GSR_P0_ADJ_C3Y GSR_P0_EXP_C1M GSR_P0_EXP_C1Y GSR_P0_EXP_C3Y GSR_P0_N_C1M  \
# 1        88.506536       0.554474        0.92971       1.376872           14
# 2                0              0              0              0            0
# 3                0              0              0              0            0
# 4        88.506536       0.906557       1.549487       1.340967           18
# 5                0              0              0              0            0
# ..             ...            ...            ...            ...          ...
# 140              0              0              0              0            0
# 141      89.029182        0.38202       0.607775       1.668393           10
# 142              0              0              0              0            0
# 143              0              0              0              0            0
# 144      89.467743       0.235003       0.369289        0.54188            5
#
#     GSR_P0_N_C1Y  YEAR MONTH
# 1             14  2020    11
# 2              0  2020    11
# 3              0  2020    11
# 4             18  2020    11
# 5              0  2020    11
# ..           ...   ...   ...
# 140            0  2022     5
# 141           10  2022     5
# 142            0  2022     5
# 143            0  2022     5
# 144            5  2022     5
#
# [3120 rows x 35 columns]

# %%
final_df = survival_final.copy()
final_df
# Out:
#                                            ENTIRE_NAME CTR_CD CTR_TY  \
# 1                         Children's of Alabama (ALCH)   ALCH    TX1
# 2                University of Alabama Hospital (ALUA)   ALUA    TX1
# 3                           UAMS Medical Center (ARUA)   ARUA    TX1
# 4                   Phoenix Children's Hospital (AZCH)   AZCH    TX1
# 5      Banner-University Medical Center Phoenix (AZGS)   AZGS    TX1
# ..                                                 ...    ...    ...
# 140     University of Washington Medical Center (WAUW)   WAUW    TX1
# 141            Children's Hospital of Wisconsin (WICH)   WICH    TX1
# 142        Froedtert Memorial Lutheran Hospital (WISE)   WISE    TX1
# 143            Aurora St. Luke's Medical Center (WISL)   WISL    TX1
# 144  University of Wisconsin Hospital and Clinics (...   WIUW    TX1
#
#             RELEASE_DATE ORG GSR_AD_OBS_C1M GSR_AD_OBS_C1Y GSR_AD_OBS_C3Y  \
# 1    2021-01-04 18:00:00  LI              0              0              0
# 2    2021-01-04 18:00:00  LI             13             20             41
# 3    2021-01-04 18:00:00  LI              1              4              8
# 4    2021-01-04 18:00:00  LI              0              0              0
# 5    2021-01-04 18:00:00  LI             10             29             28
# ..                   ...  ..            ...            ...            ...
# 140  2022-07-06 19:00:00  LI              8             14             14
# 141  2022-07-06 19:00:00  LI              0              0              0
# 142  2022-07-06 19:00:00  LI              3              5              6
# 143  2022-07-06 19:00:00  LI              2              3              8
# 144  2022-07-06 19:00:00  LI             10             20             32
#
#     GSR_AD_ACT_C1M GSR_AD_ACT_C1Y  ... GSR_P0_ADJ_C1M GSR_P0_ADJ_C1Y  \
# 1                0              0  ...      96.051354      93.107823
# 2        95.422535      92.721906  ...              0              0
# 3        98.901099      95.194139  ...              0              0
# 4                0              0  ...      95.098189      91.485857
# 5        96.478873      88.596449  ...              0              0
# ..             ...            ...  ...            ...            ...
# 140      96.718873      94.042122  ...              0              0
# 141              0              0  ...      96.258116      92.433791
# 142       94.98827      91.144356  ...              0              0
# 143      96.078431      93.735055  ...              0              0
# 144      95.422146      89.621382  ...      95.441178        90.3541
#
#     GSR_P0_ADJ_C3Y GSR_P0_EXP_C1M GSR_P0_EXP_C1Y GSR_P0_EXP_C3Y GSR_P0_N_C1M  \
# 1        88.506536       0.554474        0.92971       1.376872           14
# 2                0              0              0              0            0
# 3                0              0              0              0            0
# 4        88.506536       0.906557       1.549487       1.340967           18
# 5                0              0              0              0            0
# ..             ...            ...            ...            ...          ...
# 140              0              0              0              0            0
# 141      89.029182        0.38202       0.607775       1.668393           10
# 142              0              0              0              0            0
# 143              0              0              0              0            0
# 144      89.467743       0.235003       0.369289        0.54188            5
#
#     GSR_P0_N_C1Y  YEAR MONTH
# 1             14  2020    11
# 2              0  2020    11
# 3              0  2020    11
# 4             18  2020    11
# 5              0  2020    11
# ..           ...   ...   ...
# 140            0  2022     5
# 141           10  2022     5
# 142            0  2022     5
# 143            0  2022     5
# 144            5  2022     5
#
# [3120 rows x 35 columns]

# %%
final_df.to_csv("Resources/LI_survival.csv", index=False, header=True)
