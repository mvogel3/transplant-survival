# %%
import pandas as pd

# %%
sheet_name = '20_Year'

survival_20_df = pd.read_excel('src/KIDNEY_DATA0010625.xlsx', sheet_name=sheet_name)

# %%
survival_20_df.head()
# Out:
#   Transplant Year    Age Group  Number_of_Transplants Graft_Survival_Rate_20  \
# 0            1988      <1 Year                      7                      *
# 1            1988    1-5 Years                     81                  23.93
# 2            1988   6-10 Years                     83                  22.59
# 3            1988  11-17 Years                    271                  19.41
# 4            1988        18-34                   2076                  24.23
#
#   Patient_Survival_Rate_20
# 0                        *
# 1                    71.55
# 2                    74.51
# 3                    66.35
# 4                    50.51

# %%
survival_20_df_rev = survival_20_df.iloc[::-1]
survival_20_df_rev.head(30)
# Out:
#     Transplant Year     Age Group  Number_of_Transplants  \
# 129         Overall  Not Reported                      1
# 128         Overall           65+                   9857
# 127         Overall         50-64                  44258
# 126         Overall         35-49                  50099
# 125         Overall         18-34                  32377
# 124         Overall   11-17 Years                   4958
# 123         Overall    6-10 Years                   1766
# 122         Overall     1-5 Years                   1647
# 121         Overall       <1 Year                     79
# 120            2002  Not Reported                      1
# 119            2002           65+                   1459
# 118            2002         50-64                   4697
# 117            2002         35-49                   3885
# 116            2002         18-34                   2100
# 115            2002   11-17 Years                    385
# ...
